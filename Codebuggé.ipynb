# %% [markdown]
# # Général

# %% [markdown]
# ### Bibliothèques importées

# %%
import numpy as np
import random as rd
import copy as copy
import uuid as uuid
import matplotlib.pyplot as plt
from matplotlib import animation

# %% [markdown]
# ### Variables globales

# %% [markdown]
# ##### Variables générales

# %%
#type(n) : int
#n est la taille de la matrice carrée
n = 100

#type(nb_renards_initial) : int
#nb_renards_initial le nombre initial de renards
nb_renards_initial = 500

#type(nb_lapins_initial) : int
#nb_lapins_initital le nombre initial de lapins
nb_lapins_initial = 1000

#type(M) : int
#M le range de l'entourage de Moore
M = 1

# %% [markdown]
# ##### Variables relatives aux carottes

# %%
#type(probabilite_presence_carotte) : float [0.00 ; 1.00]
#probabilite_presence_carotte est la probabilité qu'il n'y ait pas de carottes sur une case
probabilite_presence_carotte = 0.5

gain_densite_carotte = 0.1

# %% [markdown]
# ##### Variables relatives aux lapins

# %%
#type(esperance_vie_lapin) : int
#esperance_vie_lapin est un nb de jours
esperance_vie_lapin = 2555 #environ 7 ans

#type(efficacite_lapin) : float
#efficacite_lapin est un pondérateur fictif pour éviter un système mathématique trop prédominant, c'est le facteur chance naturel
def efficacite_lapin_specifique():
    return rd.uniform(-0.1,0.1)

#type(maturite_sexuelle_lapin) : int
#maturite_sexuelle_lapin le nb de jours pour pouvoir s'accoupler
maturite_sexuelle_lapin = 310 #donnée réelle, correspond à 10 mois

#type(temps_gestation_lapin) : int
#temps_gestation_lapin le nb de jours avant de mettre bas
temps_gestation_lapin = 55 #donnée réelle

#type(seuil_lapin) : int
#seuil_lapin le pourcentage au dessus duquel le lapin cherchera de la nourriture ou à se reproduire
seuil_lapin = 0.8

gain_excitation_lapin = 0.01
gain_faim_lapin = 0.01

# %% [markdown]
# ##### Variables relatives aux renards

# %%
#type(esperance_vie_renard) : int
#esperance_vie_renard est un nb de jours
esperance_vie_renard = 1825 #environ 5 ans

#type(efficacite_renard) : float
#efficacite_renard est l'efficacité de chasse du renard, i.e. sa chance d'attraper le lapin
efficacite_renard_generale = 0.20 #basé sur des données réelles
def efficacite_renard_specifique():
    return rd.uniform(-0.1,0.1)

#type(maturite_sexuelle_renard) : int
#maturite_sexuelle_renard le nb de jours pour pouvoir s'accoupler
maturite_sexuelle_renard = 310 #donnée réelle, correspond à 10 mois

#type(temps_gestation_renard) : int
#temps_gestation_renard le nb de jours avant de mettre bas
temps_gestation_renard = 55 #donnée réelle

#type(seuil_renard) : int
#seuil_renard le pourcentage au dessus duquel le lapin cherchera de la nourriture ou à se reproduire
seuil_renard = 0.8

gain_excitation_renard = 0.01
gain_faim_renard = 0.01

# %% [markdown]
# # Agents

# %% [markdown]
# ### Renard

# %%
def creation_renard(age, position):
    ID = uuid.uuid4()
    sexe = rd.choice([True, False]) #True correspond à femelle
    efficacite = efficacite_renard_generale + efficacite_renard_specifique()
    fecondite = rd.uniform(0.2,1.0)
    faim = rd.random()
    excitation = rd.random()
    gestationnaire = (False, 0, 0) #en gestation ou non, nb de jour avant mis à bas, nb de renardeaux
    type_agent = "renard"
    
    return (ID, (type_agent, (age, sexe, efficacite, fecondite, excitation, faim, gestationnaire, position)))

# %%
#print(creation_renard(0,(0,0)))

# %%
def creation_renards():
    cpt = 0 #type(cpt) : int
    renards = dict()
    while cpt < nb_renards_initial:
        cpt += 1
        identifiant, renard = creation_renard(rd.randint(0,esperance_vie_renard),(rd.randint(0,n-1),rd.randint(0,n-1)))        
        renards[identifiant] = renard
    return renards

# %%
def test(c):
    cpt = 0
    while cpt < c:
        i = rd.randint(0,n-1)
        if i >= 100:
            return i
        cpt+=1
    return

print(test(100))
# Out:
# None

# %%
#print(creation_renards())

# %% [markdown]
# ### Lapin

# %%
def creation_lapin(age, position):
    """None -> lapin
    lapin : tuple[int, bool, float, float, float, float, tuple[bool, int], tuple[int, int]]"""
    ID = uuid.uuid4()
    sexe = rd.choice([True, False]) #True correspond à femelle
    efficacite = efficacite_lapin_specifique()
    fecondite = rd.uniform(0.2,1.0)
    faim = rd.random()
    excitation = rd.random()
    gestationnaire = (False, 0, 0) #en gestation ou non, nb de jour avant mis à bas, nb de lapinous
    type_agent = "lapin"
    
    return (ID, (type_agent, (age, sexe, efficacite, fecondite, excitation, faim, gestationnaire, position)))

# %%
#print(creation_lapin())

# %%
def creation_lapins():
    cpt = 0 #type(cpt) : int
    lapins = dict()
    while cpt < nb_renards_initial:
        cpt += 1
        identifiant, lapin = creation_lapin(rd.randint(0, esperance_vie_lapin),(rd.randint(0,n-1),rd.randint(0,n-1)))        
        lapins[identifiant] = lapin
    return lapins

# %%
#print(creation_lapins())

# %% [markdown]
# ### Carotte

# %%
def creation_carotte(ligne, colonne):
    return (uuid.uuid4(), ("carotte", (rd.random(),(ligne, colonne))))

# %%
#print(creation_carotte(0,0))

# %%
def creation_carottes():
    cpt = 0
    carottes = dict()
    while cpt < n*n - 1:
        cpt += 1
        if rd.random() >= probabilite_presence_carotte:
            identifiant, carotte = creation_carotte((cpt-(cpt%n))//n,cpt%n)
            carottes[identifiant] = carotte
    return carottes

# %%
#print(creation_carottes())

# %% [markdown]
# ### Mélange des agents

# %% [markdown]
# On déclare en variable globale le dictionnaire rassemblant tous nos agents

# %%
def merge_two_dicts(x, y):
    z = x.copy()   # start with x's keys and values
    z.update(y)    # modifies z with y's keys and values & returns None
    return z

# %%
agents = merge_two_dicts(creation_carottes(),merge_two_dicts(creation_lapins(), creation_renards()))

# %%
#print(agents)

# %% [markdown]
# # Environnement

# %% [markdown]
# ### Initialisation de l'environnement

# %%
def init_matrice():
    a = np.empty((n,n), dtype = np.object_)
    a.fill([])
    a = np.frompyfunc(list,1,1)(a)
    return a

# %%
environnement = init_matrice()

# %%
#print(environnement)

# %%
test = init_matrice()
test[0,1].append("tes")
print(test)
# Out:
# [[list([]) list(['tes']) list([]) ... list([]) list([]) list([])]
#  [list([]) list([]) list([]) ... list([]) list([]) list([])]
#  [list([]) list([]) list([]) ... list([]) list([]) list([])]
#  ...
#  [list([]) list([]) list([]) ... list([]) list([]) list([])]
#  [list([]) list([]) list([]) ... list([]) list([]) list([])]
#  [list([]) list([]) list([]) ... list([]) list([]) list([])]]

# %% [markdown]
# ### Placement des agents dans l'environnement

# %%
def update_matrice():
    for e in agents:
        type_agent,agent = agents[e]
        if type_agent == "lapin" or type_agent == "renard":
            _,_,_,_,_,_,_,position = agent
            ligne, colonne = position
            environnement[ligne, colonne].append(e)
        elif type_agent == "carotte":
            _,position = agent
            ligne, colonne = position 
            environnement[ligne, colonne].append(e)
    return environnement

# %%
np.set_printoptions(threshold=np.inf)
print(update_matrice())
# Out:
# [[list([]) list([])
#   list([UUID('5b0fa1e2-c9f2-442a-9c85-628da9e1d67f'), UUID('193911c5-3d9f-4724-9cf3-b2d038dc3fc9')])
#   list([UUID('1cd77a65-882d-43fb-9bdd-8b323ca641df')])
#   list([UUID('0aed243d-3425-48f3-86f3-3f44e25a4993')]) list([]) list([])
#   list([UUID('7bd97f4d-2c76-41c3-a219-c1365b0ca0fc')]) list([])
#   list([UUID('105490ac-8687-4d2c-95b5-0ae298325154')]) list([]) list([])
#   list([UUID('7936aaac-f503-4d24-9113-8744771b95d1')])
#   list([UUID('280bbee3-c1cf-4c38-9e14-93b1ee79517b')])
#   list([UUID('ca8ed635-2fcd-4da7-8243-bdf4529d1113')])
#   list([UUID('6466efa1-7797-477e-80bd-c48b561b6dc9')]) list([])
#   list([UUID('29e538d0-50aa-4945-8460-1ff38240d624')])
#   list([UUID('892f775e-c965-4463-8a9a-ae81e65631ba')]) list([])
#   list([UUID('045ec62d-da6d-4d30-9031-ffd2d25d43bb')]) list([])
#   list([UUID('bb1de90e-38ec-4641-b84a-33baaa8427f3')])
#   list([UUID('4892e4d0-33a5-4473-bf43-04483382714a')])
#   list([UUID('7ebcf878-da84-46f9-b991-e055f7c92977')]) list([])
#   list([UUID('8245ccb8-8ff4-4c32-86ad-ca8ec1bd1712')])
#   list([UUID('5a071c81-e9fb-4e88-9fa2-ef70281fc27d')]) list([]) list([])
#   list([]) list([]) list([]) list([])
#   list([UUID('5ca257df-26fd-47f4-903b-affe00d9fe9e')])
#   list([UUID('172eea48-64df-4a4f-a597-34f35de56fe3')]) list([])
#   list([UUID('c2111011-6024-4374-a2c4-cab5d24c5e5b')]) list([])
#   list([UUID('68e443df-1bf9-47a4-9b16-41035ad75a34'), UUID('0187a05a-87d6-44d2-b1d1-3671cc6632df')])
#   list([UUID('09576328-6d7d-4657-915e-451c6c8921aa'), UUID('1045cb2e-e567-485d-8d5d-5554cfbca67a')])
#   list([UUID('57358e61-6a55-4107-b2b6-13a401c7bb24')])
#   list([UUID('98f7a1e8-1066-4d6a-be5b-0233651c9375')]) list([]) list([])
#   list([UUID('5c5416ec-a39d-4a1f-8cae-af41bcc989dd')]) list([]) list([])
#   list([UUID('479dc969-f9e7-4e52-a20b-0677770dca77')]) list([]) list([])
#   list([])
#   list([UUID('e5e2f8fe-b10a-4049-a0b5-98de794e8478'), UUID('6d44a2e9-6337-4fc7-8203-e374004dfd99')])
#   list([])
#   list([UUID('d3e4da87-c14e-4eb0-b97f-9b09872b548c'), UUID('fb96e242-7573-4815-a7d7-e82c0526336a')])
#   list([UUID('045e0436-43b3-4ea4-a89d-fdb25e4d17ad'), UUID('8b3cd6b8-539b-449e-a8cd-d07b6d3702fa')])
#   list([UUID('98ac341c-a8f6-46f2-bd2b-46959b1edba7')])
#   list([UUID('4e373dbb-6a6d-49e8-b952-c3db389c79e7'), UUID('0fc7aed2-309e-4db2-bec1-52d521601033')])
#   list([UUID('82b946e4-6ef3-4d13-82a8-60108a663240')]) list([])
#   list([UUID('e2bfc341-de97-4b80-a217-493690beaa58')])
#   list([UUID('24778b21-9029-4ca2-bf67-d8692489f65b')])
#   list([UUID('6f99de58-ac41-4715-95ef-3c5ee84d7f8a')]) list([]) list([])
#   list([UUID('665d96a4-86db-45cb-a1b8-61dd55f753ce')]) list([]) list([])
#   list([]) list([]) list([]) list([])
#   list([UUID('380fed51-689c-4b64-8c68-5193fa26602f')]) list([]) list([])
#   list([]) list([UUID('cb3a7a1d-0bdd-4a41-b222-12e789e3b8b2')]) list([])
#   list([UUID('3122b0a9-2b48-4284-abfd-9b60cd03446d')]) list([])
#   list([UUID('500222b9-308c-46c6-bb44-7bda6b677df6')]) list([]) list([])
#   list([]) list([]) list([])
#   list([UUID('08a09ce6-0b1d-4b4e-b3e4-5f58d151a16d')]) list([])
#   list([UUID('f986bd54-24f1-4b00-9d0e-061b9a3601e7')]) list([])
#   list([UUID('33de5354-8b37-4433-818b-994eacc28afe')]) list([])
#   list([UUID('b8ee1f19-2651-4057-b1a9-e471346960fd')])
#   list([UUID('ce1be97f-bab0-48f2-a352-7f5871feb783')]) list([])
#   list([UUID('da5c9c25-9e8f-4829-9eda-2136c926cd57')])
#   list([UUID('d1b8e5cc-2a26-4db7-937b-1b2661ee6026')]) list([]) list([])
#   list([])]
#  [list([]) list([UUID('62401e80-a497-447d-9434-a088f41b0e1b')]) list([])
#   list([]) list([]) list([UUID('325cc5f2-21dd-4027-9665-27705716c97d')])
#   list([UUID('4adec7b8-96da-483a-abd3-bf46920f347c')])
#   list([UUID('42742295-35e1-4454-9605-973ca2f89932')])
#   list([UUID('f34cb4f0-1271-47f1-ac30-cb1b1a34a393')]) list([])
#   list([UUID('b3c1079e-3715-4a2e-a207-572d88fe55f9')])
#   list([UUID('07f7b211-e387-4e49-8266-0d0c2c409a1a')]) list([])
#   list([UUID('40c74df2-6d8e-480f-9718-d016b8b60119')])
#   list([UUID('51bf75ec-4456-4722-9611-1613128c9439')]) list([])
#   list([UUID('10a2be7a-14a3-4dd3-b036-3d1fd5519969'), UUID('c1d9cfc8-1479-4fb4-8a2c-49585f2e72ad')])
#   list([]) list([]) list([]) list([]) list([])
#   list([UUID('b60e622e-7167-4ec1-adcd-f5ace0cb743a')]) list([])
#   list([UUID('d2f75002-a3b2-4a3a-b4dc-6607130c0088')])
#   list([UUID('dc74dd5e-6cef-44c5-b1a3-3dac96722927')])
#   list([UUID('73a15466-2eb2-425d-9833-be7be3b38c87')])
#   list([UUID('47c6b27f-9ccb-43f6-87d6-ded810bf6c50')])
#   list([UUID('49338626-a080-4ae6-b73c-d25f8e97654e')])
#   list([UUID('1725d109-8e3a-4139-9fa5-111957cffd25'), UUID('46a6c760-b0c2-41d4-b1e9-baf1e5e5d114')])
#   list([]) list([]) list([UUID('c594d50a-4f48-46d5-9814-6fb702d76f34')])
#   list([]) list([]) list([UUID('c91a8f97-991f-43f3-b7d7-a4fd4326e0e9')])
#   list([]) list([UUID('b3cc9750-4a12-41fa-a709-6fa127ded005')]) list([])
#   list([]) list([]) list([UUID('fa36b271-64f2-47e1-86d6-145b6e662718')])
#   list([UUID('2646fd1f-4a89-474c-9e9c-32d0dd4ad5c4')])
#   list([UUID('b316aba8-49fa-4ef6-a29f-b5b00ea37bd2')]) list([]) list([])
#   list([UUID('2c124947-1359-4d6a-8d9f-bf906af48220')]) list([])
#   list([UUID('72141017-ae19-4316-8598-81315b8d5bc1')])
#   list([UUID('4a6e7d84-6b61-49d7-918d-8d8731ff4ddd')]) list([])
#   list([UUID('29a5cf5e-c5c6-4ef8-8647-c513eb04ac5e')])
#   list([UUID('5f164d27-3492-49f4-bbed-8b5bc0b1297f')])
#   list([UUID('b5dbdf1a-d5ab-4de2-ac22-09f26b12eedd')]) list([]) list([])
#   list([]) list([UUID('f1c8ff55-8e13-4b3e-91e9-67e9f2d820d1')]) list([])
#   list([]) list([UUID('2efceaca-870c-4ea8-8080-899f9c843944')])
#   list([UUID('92b44eb8-5274-446c-b11a-f4301513d444')])
#   list([UUID('b4e131f7-d1dc-48c0-a346-f441f52eec34')])
#   list([UUID('9e933310-fc23-425e-9159-df7e9993fff5')])
#   list([UUID('cfcf8518-d553-4f3b-962d-75d81ef55276')]) list([]) list([])
#   list([UUID('c85fc808-1e89-4502-8292-58453af673bb')]) list([])
#   list([UUID('069b9640-28e0-414a-8c12-c070fddbb098')])
#   list([UUID('ed405736-fc5f-4ad6-a770-f5da2468a0b7'), UUID('8ab80c6b-e53c-4db0-a447-3f913d26f11b')])
#   list([]) list([UUID('35978bbb-0767-4f33-80fc-660f4fe806dd')])
#   list([UUID('10f6820e-1a58-45a5-8eb7-309f01880846')]) list([])
#   list([UUID('75455d3c-5740-4503-a980-989bd28d10cc')])
#   list([UUID('10b4b159-3da6-40d4-9e79-be01a32330ec')])
#   list([UUID('fa507603-a3c1-42ee-a328-ee9642587269'), UUID('a78a9e6a-8e78-41dd-8689-7afe79cca521')])
#   list([UUID('b519e943-9250-42cb-bd33-49130f7c4250')]) list([]) list([])
#   list([UUID('09e650b9-fd23-483f-b579-213adab8fbe4')]) list([]) list([])
#   list([]) list([UUID('2d29c4b6-bef1-4e7a-b029-53039021d28d')])
#   list([UUID('dae4e1ef-bf0f-4103-865a-90d9e1c5e3c4')])
#   list([UUID('e3d5ac03-0fb4-40de-930e-e02f3122498e')])
#   list([UUID('0ada1ccb-de0d-46b8-9151-79776513195e')]) list([])
#   list([UUID('3d700360-0c65-4b4d-8339-56f606c6922e')]) list([]) list([])
#   list([UUID('67262949-f488-4d35-849b-2b59dfd1b282')])
#   list([UUID('55614031-a831-4649-b65b-f8973f67025a'), UUID('af317b21-f97e-4bd6-b92f-a7288dbee069')])
#   list([UUID('7d209cc1-bab3-4df5-875a-8352e47a7369')]) list([]) list([])
#   list([UUID('4a36b515-5695-4fda-ad9b-e4fa869a8b82')])
#   list([UUID('4acf8545-0950-47de-ae0a-74ebdf36d84e')])]
#  [list([]) list([UUID('f94ba92b-847b-4dc6-8ebf-e5db7a456a89')]) list([])
#   list([UUID('ce31f5ea-908a-4854-a49f-07189ab1999b')]) list([]) list([])
#   list([UUID('449dddf5-4292-4c20-ac90-47dc92e64547')])
#   list([UUID('c26a53ef-1794-4599-ad69-f75dfc623680')])
#   list([UUID('f6c2b7be-52d3-4c3e-b272-ef2c2c3878da'), UUID('7761d3f9-128b-443b-a32c-5c79864d42c9')])
#   list([UUID('acd729f3-efae-41fd-b80d-7c1c08ebfed0')])
#   list([UUID('44e7b606-4840-488c-b757-8c1d9450db1c')]) list([]) list([])
#   list([]) list([]) list([]) list([]) list([]) list([]) list([])
#   list([UUID('13bbb6f4-d460-420a-8734-5d6413be7ccc')]) list([])
#   list([UUID('949a6321-8d19-44e7-81ba-1d00450bcf0d')])
#   list([UUID('98de7293-896c-40bc-9669-8b8f787feb29')]) list([])
#   list([UUID('811cb59c-6b13-4f80-89a2-f82f404ef375')])
#   list([UUID('ecc9a61e-4fac-4ff1-bdc9-36fc26e7b34a'), UUID('af62f744-315f-4f7d-bbd4-16c4efa642f1')])
#   list([]) list([UUID('5cbb8e8c-15cb-417b-a2fe-03b853678a52')]) list([])
#   list([]) list([UUID('a1db53ea-09c3-4120-989a-afe3ef760b4a')])
#   list([UUID('8b1a7b9f-93e5-44db-a789-1500e0d604a1')]) list([])
#   list([UUID('a1fc59c6-e98e-46fd-a91b-d349f1fb4a6e')])
#   list([UUID('6874625d-b545-4602-a912-3c5bc60b839b')])
#   list([UUID('af988984-4e88-45aa-9b42-bcd1af4f0207')])
#   list([UUID('1f053cdf-3783-45fe-a9b6-4a42bc31fa6b')])
#   list([UUID('91db6851-6f6a-4e2f-a6e6-7423339df698')])
#   list([UUID('14db60ca-ff94-43fe-bd58-b2bcbbe428da')])
#   list([UUID('5d94bf2d-b2ee-4ca5-88fd-b5322df53ef7')])
#   list([UUID('57025538-71e2-41af-b65a-c3f1e9f5806b'), UUID('ba8fe6ef-1133-4cf7-b008-227fdeb76fb5')])
#   list([]) list([UUID('fb7de0d8-fbf7-45db-a729-c4fe6305e201')]) list([])
#   list([UUID('6954e5ae-4480-4800-b952-788918d35cae')])
#   list([UUID('2d81ad81-0258-416c-b817-e6ab3ef77f91')]) list([])
#   list([UUID('a615e579-083b-4ed7-8966-018c37f6d74f')])
#   list([UUID('8a988828-9c3e-4cca-a2da-ee577aebc014')]) list([])
#   list([UUID('82c0d299-0527-4c9b-bcce-67e03a47342a')])
#   list([UUID('4eaedcef-4583-4904-8b3e-d393b31a0823')]) list([]) list([])
#   list([]) list([]) list([UUID('c674f31a-4bfb-425f-8b2c-e5705dce0197')])
#   list([]) list([UUID('bcc9571c-5e44-49e8-b085-5a84e9f3b277')])
#   list([UUID('9ad2a77a-d4ec-4d8b-9e52-419a7c8c0e29')])
#   list([UUID('84ee34fd-b922-4024-bc4a-fe7909e9b6bd'), UUID('cab2d98f-18a0-4f9d-b6d8-7daf74d9fe75')])
#   list([]) list([UUID('ce26393a-155a-4387-a732-dd91785617fc')]) list([])
#   list([]) list([UUID('871c70b4-b034-49ca-a613-2e1ab7125fec')]) list([])
#   list([]) list([]) list([UUID('e99b6bb1-022d-4967-ac90-e12249e2602c')])
#   list([]) list([UUID('eaf37b64-9cc9-43fc-aa81-93bfda7a3adb')]) list([])
#   list([UUID('f8a6f6bf-2ddf-4baf-b603-d6d6297d97c2')]) list([]) list([])
#   list([UUID('907fdc34-a3d9-4d74-8a79-0704de1c63ab')])
#   list([UUID('24f3fd0b-b1ed-4bde-8043-5bfc7c2ca1be')])
#   list([UUID('5cbd6bb3-8e25-4612-97bb-a31997a889d1')]) list([])
#   list([UUID('a060a6ea-5b11-4b91-be27-9edce3c00c04')])
#   list([UUID('b2e04a20-2c92-4a02-94a4-c213af01193e')]) list([])
#   list([UUID('a686a553-2c9e-45e5-96ee-de596ed0ae48')])
#   list([UUID('a07479d4-f209-49e2-a5fe-59b09af2d4fb')]) list([])
#   list([UUID('a0d39ed6-c8a3-431d-8919-e691cf397eca')]) list([]) list([])
#   list([UUID('221dd64f-b420-4d37-9abd-2775dfb7c6c0')]) list([]) list([])
#   list([]) list([]) list([UUID('c1a1e6b6-283d-4395-a51c-74f8e5047359')])
#   list([]) list([]) list([]) list([])]
#  [list([UUID('ad003a19-fcac-4b12-b478-71bbf20e098b'), UUID('8c214988-669e-49b7-9d48-198479d298e0')])
#   list([]) list([]) list([]) list([]) list([])
#   list([UUID('4a04cd03-306a-478d-a750-6492fd71cd14')])
#   list([UUID('be846026-4149-41ab-8af9-a5eefd8422c6')])
#   list([UUID('e84eeb92-3455-4651-a446-9e180bce2f29')])
#   list([UUID('ca758395-b403-4d5f-87e3-dc85244556a0')]) list([])
#   list([UUID('ddf92213-7463-4837-8a45-00784fba9f57')])
#   list([UUID('e69d66a2-fb69-40ec-97dd-a5339108bea3')]) list([])
#   list([UUID('56792ad1-33ed-4cfd-88f9-b6572b7e4ff2')]) list([]) list([])
#   list([]) list([]) list([])
#   list([UUID('181030c7-cb3e-446e-9c28-edc37055bfba')]) list([]) list([])
#   list([]) list([UUID('6a0906cf-7ebe-4c29-a9dc-0fae6cf92802')]) list([])
#   list([UUID('cfd35839-d48a-4368-81a3-e67aa7323ced')]) list([])
#   list([UUID('12546ade-b680-4421-85af-e5d4e51238a9')]) list([])
#   list([UUID('6cd53a9a-5bcc-49de-b62c-571d492ea25b')])
#   list([UUID('c6da0a75-9f6d-46e4-8293-23b48dbf7df4')]) list([])
#   list([UUID('4bb2c5b3-09d1-46c9-9472-3832b2ebe4b0')])
#   list([UUID('a0147830-b2f7-4f69-ac73-57c3a5e6f9b3')])
#   list([UUID('df6484ae-a70c-4695-be5d-389c34dc72eb')])
#   list([UUID('1f827238-3f22-4ae8-8dfe-238d0682ac11')])
#   list([UUID('cac71406-b61d-4988-bc67-9a762a6583e7'), UUID('c2f75346-4a0c-458c-95c7-58ca020ab60f')])
#   list([UUID('366aa1f0-2ba2-4a11-beee-3ef072971543')]) list([])
#   list([UUID('5db48174-6d46-4b6a-9daf-ab0f4f5b9432')]) list([]) list([])
#   list([]) list([UUID('9dba6ed3-ecab-49f0-8133-5cc740f00484')])
#   list([UUID('729a3e3b-7c38-41ff-bf0d-714e584d8e3d')])
#   list([UUID('1571b212-f25e-4181-944d-eeb28682c4b1')])
#   list([UUID('83fa1dd0-440c-4e32-bac3-85f16730ea9f')])
#   list([UUID('2915ee09-5941-4ae4-b7d0-a51537622441')])
#   list([UUID('c85059bb-0ac6-4f98-88bc-87b58d78ecb2'), UUID('95ebc9d9-1718-4b84-b292-05156d38a003')])
#   list([]) list([UUID('e720e5f1-fa7b-4a6b-8302-d34befba209a')])
#   list([UUID('27ec5fb7-30f2-4f16-8b7e-b9120a8686e2')])
#   list([UUID('7e6faae5-43ff-4923-abca-44671db9c42b')])
#   list([UUID('35c759c4-6a4b-4400-b973-b4330c0d9217')]) list([])
#   list([UUID('c324d540-ab33-4207-8a02-d9d89cf48b98')]) list([]) list([])
#   list([]) list([]) list([]) list([]) list([])
#   list([UUID('d6577d09-bbbb-40fb-a900-0487ce75ddee')]) list([])
#   list([UUID('6c0603fb-63b8-44ec-96ec-56835bbd599d')])
#   list([UUID('25773a49-70af-45af-8a1c-9b31db1ba1a7')])
#   list([UUID('a40ad815-04e5-47dd-853f-cf3d69cca051')])
#   list([UUID('981f9e2c-8ae1-40f5-a390-fedad50bb4c1')])
#   list([UUID('bcdde878-546d-4620-ba56-5f204caa9589')]) list([])
#   list([UUID('14a559fd-164f-4846-9c61-499b4734d789')]) list([])
#   list([UUID('9da26bf0-6bed-4e2a-a082-09da216e60f8')])
#   list([UUID('224dd958-4576-4260-91a9-70b08047f4a5')]) list([]) list([])
#   list([]) list([UUID('19fa9037-d41e-420c-9bcb-4c5a6d689d52')]) list([])
#   list([UUID('e43a6803-c7f6-43ea-816a-38e940c7774a')])
#   list([UUID('5e9e0ae4-1ff3-4e59-87f3-43082a3e934d')])
#   list([UUID('7da5623c-4e24-4daf-b539-cca83ada01ed')])
#   list([UUID('5b487be0-19d5-4896-9e72-0966c40dc0ed')]) list([])
#   list([UUID('0ea367cf-cba5-4c22-8c05-49b024397d48')]) list([]) list([])
#   list([UUID('5babc91e-afde-4b03-9ecb-42da19ee0413')])
#   list([UUID('7baaf5b6-c9bd-4d6f-bbc8-eba88c774c6c')]) list([])
#   list([UUID('b60e92dc-5dc3-4754-9c43-442ce690f682')])
#   list([UUID('6f5e93b4-5a7b-4cc7-8018-53cc85166954')]) list([])
#   list([UUID('49fdeab8-6e84-4dc7-baf5-abb5d8ae89d1')]) list([])
#   list([UUID('bba2f61d-daba-45bf-ab69-27c71898c55f')])
#   list([UUID('a0c47ed8-ca1c-45bf-93a7-759b9483d2ad')]) list([])]
#  [list([]) list([UUID('25ac686e-5541-463b-a8b4-a2f9dddfea5f')])
#   list([UUID('788652d3-4671-4634-99d6-7eded796911a')])
#   list([UUID('7be02548-9199-40c3-b052-2541f69fcfe0')]) list([]) list([])
#   list([UUID('a5783e9e-520f-4084-b756-de4c47fc605d')])
#   list([UUID('506253e0-ed2c-49d0-b949-ae105326c705')]) list([]) list([])
#   list([]) list([UUID('36b512c1-1159-47ab-b224-022ea0f15c0b')])
#   list([UUID('04b84c3a-7b31-49cf-9af6-9ea1a8ff8593')])
#   list([UUID('3b17c92e-bd5e-404a-8c87-8f687a93110b')]) list([]) list([])
#   list([UUID('0c633677-482b-4da8-b226-e87465b4521a')])
#   list([UUID('8e99533c-0d0c-4def-85f0-f990a515ae81')]) list([])
#   list([UUID('84d6469c-34f5-44d9-9bed-e2a95ec511bf')])
#   list([UUID('253ccdef-2809-4019-bddd-438f635e9d96')])
#   list([UUID('1ba2d079-3949-4922-91aa-21f1c2b6ba3a')])
#   list([UUID('fbf14689-3a93-4174-a4ac-7442094baabe')])
#   list([UUID('7f56ac24-4771-4c55-8fe7-fa4caa1c19b6')]) list([])
#   list([UUID('e9ccc348-9555-42a4-8c69-aedd4cb4471d')]) list([]) list([])
#   list([]) list([UUID('dc8278d9-6665-4506-b66f-7b87e30bbdfb')])
#   list([UUID('c6e43a01-2339-4ee8-ab07-2ccba09e289d')]) list([]) list([])
#   list([UUID('3a8b272f-04c1-44e3-8c4e-0e22a3a4f696')])
#   list([UUID('d9ce8c71-34ca-4c97-bb14-fab8cf4b4bd8')])
#   list([UUID('b82cf994-99cc-4e4a-81f4-b5b88b85b0cc'), UUID('4c59e7ab-b0f4-443c-9e89-dec8bd95dc84')])
#   list([]) list([]) list([]) list([]) list([])
#   list([UUID('5e6e359f-750c-4752-93f2-a656764daded')])
#   list([UUID('7a63aca7-10be-45dc-836d-a9c64b2a8e00')]) list([])
#   list([UUID('fae46c66-0171-43d8-afa8-4c75c0a4798f')])
#   list([UUID('38ca962a-0b2a-4843-979e-e3c23aba9da0')]) list([])
#   list([UUID('ed900e08-4066-4f47-8a68-26b38b5c15ea')])
#   list([UUID('9cdb13c9-274c-4929-98ec-8b3db16038b5')])
#   list([UUID('ed7a2a0e-6437-45e7-9ef8-c2cc337917fa')]) list([]) list([])
#   list([UUID('5caffa8f-6fa2-4fdf-a279-417587082a49')])
#   list([UUID('acd6f30e-087b-4a9d-a074-4d8bfe23bc0a')])
#   list([UUID('80b15a1b-1a9b-4fb7-b597-94b9923f34f5')]) list([])
#   list([UUID('06cb7647-0788-4144-bef9-60e3b8b04d7e')])
#   list([UUID('3074f75d-16be-41b0-8c6a-4044295ed363')])
#   list([UUID('9fc76f40-6b63-451f-a880-251b75e3c31e')]) list([])
#   list([UUID('8d934baf-55cb-4c2d-a41d-9514d2789340')])
#   list([UUID('082c7a62-eab5-44e6-b78e-3f1705eefbc0')])
#   list([UUID('a30fd33d-7679-47e9-a7e3-8bd3be6ffffe')])
#   list([UUID('96a2fe2c-fd6a-43d5-ac61-7b036f3ea5c2'), UUID('620780c1-7b06-45e3-9ff7-f06c96141260')])
#   list([UUID('54d7b0ac-fa54-4324-aee7-5c8b84919ee7')])
#   list([UUID('fd12d47b-e5e1-4a44-9cca-d811f8d93c68')]) list([]) list([])
#   list([])
#   list([UUID('956f0fb8-3d54-4978-8e68-7d79f0ba4bb8'), UUID('fdcb1038-d709-445e-9704-c2f72eb08db2')])
#   list([UUID('e3d2555c-8084-454d-8b12-15209cb9ae1f')]) list([])
#   list([UUID('7ecf159b-fadc-4038-9e3b-80750e59e186'), UUID('1002f22a-fb13-475e-bcf2-57f44bf178ac')])
#   list([UUID('f412b2b3-4466-4822-bb00-0fd8f0084606')])
#   list([UUID('e5f8bd98-9403-4fd3-a95f-3eb88e7c2c05')]) list([])
#   list([UUID('df9b44bf-7c19-4852-aebf-7a68a4d81119')]) list([])
#   list([UUID('5e7c8ed9-580a-4f59-a691-6de3ab9e06df')]) list([]) list([])
#   list([]) list([]) list([UUID('b0f72be6-b1fe-4c28-9cea-d42c012a85fb')])
#   list([UUID('2f30464e-19a8-401b-9fc8-b00a677b7e12')])
#   list([UUID('e1f176a9-2426-42cb-8888-223ca429e577'), UUID('98c1329c-85d1-427a-b4a2-ff1ea50b6779')])
#   list([]) list([]) list([UUID('b41cc47a-9589-4940-9f1b-9342e0b763ce')])
#   list([UUID('9840a3da-48fe-493e-bdfd-bc9d2291865d')])
#   list([UUID('a9e1c597-7769-41a1-82ed-a17e13b12b4e')])
#   list([UUID('b56f8ae2-6fe1-4103-9d1d-a1964f728d0d'), UUID('f9eb7f08-f7ce-4881-b51f-794b599e24c0')])
#   list([]) list([]) list([]) list([])
#   list([UUID('84c90d11-58a3-41a5-b4f7-5a6c30c2cd8a')]) list([]) list([])
#   list([UUID('47c42a45-54c3-4bfc-aa04-76062246a33e')])]
#  [list([]) list([UUID('142924f7-ec31-4438-bbf1-a8de2de28a2a')])
#   list([UUID('0d58410c-5d77-4ed8-8997-89468f851e46')])
#   list([UUID('b2fdc0b2-cc12-4caf-a758-34e06e82396a')]) list([]) list([])
#   list([]) list([UUID('021d9723-ddf5-46e3-a68e-16d9bb6bf9aa')]) list([])
#   list([UUID('8d16d248-8087-4f82-bbe8-dbe32c1b4816')]) list([]) list([])
#   list([]) list([UUID('bfba0623-ea88-4db4-b763-40eb6d5b97d6')])
#   list([UUID('dad967e7-20ae-4830-919a-b1f91225ec7f')])
#   list([UUID('b70190d8-faa3-41ce-a53f-ae65efe4cdb0')])
#   list([UUID('2f99054a-eba1-4660-95a0-16d1f51bb171')]) list([])
#   list([UUID('1f080a54-c5a1-4969-95d2-4a3e8c1e6566')])
#   list([UUID('b84ed0f0-1fc3-4518-9c2f-f70473a61e89')])
#   list([UUID('6ec24d1b-0dd1-4438-80bb-9375c2d56ef5')])
#   list([UUID('8620159c-6581-4c62-9093-083df1de030e')]) list([]) list([])
#   list([UUID('e3d88cf2-1609-4b90-8b82-b18b4c1b8d80')])
#   list([UUID('bc69253b-ac04-4d5d-8c75-ea1f91a65b10')])
#   list([UUID('ba161944-55fb-4867-9ccc-dbb55deac004')]) list([])
#   list([UUID('7272b23a-db4c-4a38-8be1-0ccdaf89847c')])
#   list([UUID('67afa647-1b74-41b2-ab10-841f85a1ad8a')])
#   list([UUID('d85ecc10-8c58-4f2f-8727-ac8b4793e644')])
#   list([UUID('0f8fd598-754a-4533-a200-b94761df0e31')])
#   list([UUID('181e9c13-0628-4924-9858-dbde0bc0b266')])
#   list([UUID('5bed9618-6b77-47e3-9eb5-23cdaa47d364')])
#   list([UUID('86f5683c-7ce0-46fd-94b5-e57b753e71cd')]) list([]) list([])
#   list([UUID('aa72aa03-fda2-4e01-b5f7-b430903cb191')]) list([])
#   list([UUID('ebc32d42-3e71-4f14-8103-e10fed4c536a')])
#   list([UUID('5c17a6c0-1b0f-426e-9080-123d6521499d')]) list([])
#   list([UUID('a251ecc7-e47a-458b-b870-88ae295b447c')]) list([])
#   list([UUID('690255c5-01a3-4012-ae0b-312378e12347')]) list([])
#   list([UUID('9e07e9f6-60b5-4259-8465-c2d610ee1d60')]) list([])
#   list([UUID('cbe0d4b7-b23e-4b4a-949a-1bdb2df69887')])
#   list([UUID('cbaa4c31-1303-43fe-aef2-d8969e806c65')])
#   list([UUID('172f5a9b-d48c-4e2e-a66e-ec643796f441')])
#   list([UUID('a4055273-f8d6-4f70-b66a-e57bdb3670d3')]) list([])
#   list([UUID('ba879cf0-6b55-4376-bdb8-cc52130bdff7')])
#   list([UUID('9e55469b-4de2-47c6-b067-563bc645c496')])
#   list([UUID('378abf6b-c025-4497-8090-192796bfc1d9')]) list([])
#   list([UUID('5a353506-753f-4a7d-b054-30c49535586e')]) list([])
#   list([UUID('37bf1583-a98b-4594-86c2-4b6da2f91b5a')]) list([])
#   list([UUID('21971993-221b-4f42-a867-f0577f907356')])
#   list([UUID('a7e8d1a8-4993-46bc-a93d-81da5e4aa1c6')]) list([])
#   list([UUID('49dc4140-8f48-4635-a23d-666cd1691e6a')]) list([]) list([])
#   list([]) list([UUID('7f08ba4a-c3b6-462d-90b9-afb267f05c7f')]) list([])
#   list([UUID('c4bd762b-670b-4c3c-b108-abc83b9d757b')]) list([]) list([])
#   list([]) list([]) list([UUID('4e74a47d-5a5a-46c6-98a3-bce824a7cce0')])
#   list([]) list([]) list([])
#   list([UUID('0d10a7ed-4af6-4f4d-9ae7-9e08903ce31e')])
#   list([UUID('6ec2c54f-2cba-4e39-9c1a-bc23c9fe450d')])
#   list([UUID('5735df3e-b008-4d05-92cc-bc57245455de')])
#   list([UUID('3e55fe91-11ae-4300-b01d-e54b9996ecad')]) list([])
#   list([UUID('af642f22-5fee-47f7-9bea-dcf7e32dfedd')]) list([])
#   list([UUID('8e3f1b6b-fdcb-492a-8223-8b4d091cabe2')])
#   list([UUID('95180e2e-18d2-47b8-a6fb-2b19832a9022'), UUID('ed591a29-0a67-4df6-b88f-82e1e66438a8')])
#   list([]) list([]) list([])
#   list([UUID('0e43ffd4-d9c7-463f-a5e2-25f019d010a0')])
#   list([UUID('dd57296d-df6c-446b-9f0a-2ae0d4f65278')]) list([])
#   list([UUID('c9256ef0-6154-4cb2-8c95-1b91930cb95f')]) list([])
#   list([UUID('72e0d8b7-6be1-453f-a436-d34583abf1db')]) list([]) list([])
#   list([])]
#  [list([]) list([]) list([])
#   list([UUID('e8034a06-4dcd-4e70-837a-ca7f84f23936')])
#   list([UUID('b36db0ee-4041-417c-8439-a7d13ad53c71')]) list([])
#   list([UUID('833ae2bf-4b0a-491a-9bd5-53872c562958')]) list([])
#   list([UUID('0c3213c4-777a-47fa-ae05-64f3be962239')]) list([]) list([])
#   list([UUID('ecf0bae2-5686-4b80-aa1a-632b4c5df742'), UUID('8bc7e78f-be19-44a3-b2f3-f386004d307e'), UUID('3d803a97-b82c-4a3a-a5fe-02fdc2f2930c')])
#   list([]) list([]) list([])
#   list([UUID('757222e7-6410-4ffe-8f02-04f5f493133c')]) list([])
#   list([UUID('725081aa-7fbe-4618-9dca-d763b15b111f')])
#   list([UUID('cac7a393-efcf-41a2-beaf-502beffdc408')]) list([]) list([])
#   list([UUID('9d29b309-2d41-4b89-8c90-f01e406ca726')])
#   list([UUID('13b55a08-4a89-4a4e-88a1-769a49fa563e')])
#   list([UUID('8cc4061e-4833-4aba-8024-d4593f0bd6a6')])
#   list([UUID('7599c1e0-0c62-4420-80f6-eb1a0a927db8')])
#   list([UUID('e078045f-bc0d-4748-ad3d-fc006db65a38')]) list([])
#   list([UUID('5bbffada-5e9e-4cb2-accc-39294a6c3233')])
#   list([UUID('e1d8f6ae-d97d-4de2-9a4d-477832174178')]) list([])
#   list([UUID('34c5b584-e870-45b9-b5b9-b4d4c57ea71f')])
#   list([UUID('7b1e5911-ec16-4006-808a-e6e7b0b4d753'), UUID('5de315b4-c54e-4f29-b363-0320035e68d0')])
#   list([UUID('dde84f65-c3d6-4a56-a1b8-2cb4b053412d')])
#   list([UUID('1707eb2e-dc34-47e7-a9f0-b32f5fb08232')]) list([]) list([])
#   list([]) list([]) list([UUID('6c0c2b40-996f-4117-be59-97c95651fc9c')])
#   list([]) list([]) list([])
#   list([UUID('f5d7217d-2fe8-4404-be77-a38bc2fc4986')]) list([])
#   list([UUID('a7fa47d6-ade5-4a42-8808-9ed42d719157')])
#   list([UUID('abdc41d7-3a13-4cf7-9a51-e096162da66e')])
#   list([UUID('c53930e1-7893-4e6d-ba0d-b92b3f36a65a')]) list([]) list([])
#   list([UUID('7b57b24f-74a8-47a1-a4f7-5a726ce5ae8f')])
#   list([UUID('d7c3ec3c-e7b7-4a73-bc4c-1fd8e57dda14')]) list([]) list([])
#   list([]) list([]) list([UUID('a349ec36-2818-4bd4-99b0-e4fcd3a0649b')])
#   list([]) list([UUID('73325c62-8c2f-4e59-9ffd-d6b6929c0398')]) list([])
#   list([UUID('0b8bae2c-87b7-40cc-b637-3b3a0c13c62f')])
#   list([UUID('5d6d5108-0775-4414-b0c6-ee7513d51a18')])
#   list([UUID('d98dd533-cfde-401f-8521-90bcd6ec23f4')])
#   list([UUID('7f919829-0cb0-436a-9f26-b53e6c4da863'), UUID('1e0e7598-0c3a-49ae-9e68-cd3144cf0a0c')])
#   list([]) list([]) list([])
#   list([UUID('56971c2a-a9de-40b3-87d6-b1d939766dd4')]) list([]) list([])
#   list([]) list([UUID('c54457eb-359c-4081-aaa9-7f0a5e8fe98b')]) list([])
#   list([UUID('7c73ccb9-4db5-4fec-a4e8-6acca87f080a')])
#   list([UUID('4e37ad2f-b827-484f-a213-1c05a6d28676')]) list([])
#   list([UUID('32b0194e-294f-447e-b610-154fc29d1541')]) list([]) list([])
#   list([])
#   list([UUID('93acd13f-5139-4d13-99a8-be7da80c7882'), UUID('5025b373-b782-41fa-b93c-3dbbab2e2311')])
#   list([UUID('11e1ea40-d881-429e-8e3b-89420ff01e1a')])
#   list([UUID('3c62cb9a-1ce7-4783-a30b-4bad2a6a1681')]) list([])
#   list([UUID('911c5785-3068-45c0-ba71-81ba0a800047')])
#   list([UUID('54d48408-ab12-4f21-aedc-9060d55f81c8')])
#   list([UUID('78196701-5b4c-4ace-83af-15043874a7f6')]) list([])
#   list([UUID('ee170397-5db4-4578-97fe-283bc7c3bebf')]) list([])
#   list([UUID('cca6f726-7ca6-42d1-b959-472f002fb50e'), UUID('eabd1144-7022-42f2-80cc-263335c7b004')])
#   list([UUID('8ea9c025-c9b0-4583-a9df-df950a1f8359')])
#   list([UUID('ed1f32fa-5354-42c7-b928-cc55f3d3da8e')])
#   list([UUID('34178a61-49d2-4cc5-957e-0af710c188b1')]) list([])
#   list([UUID('8c7146f8-3c8a-4897-929f-20929d3679a3')]) list([])
#   list([UUID('0a500e1b-2308-4270-b1aa-705005a64f80')]) list([]) list([])
#   list([UUID('383406ac-fdc2-44ff-b11c-7bbe78da1ccc'), UUID('f8423ff5-22fa-48bc-9532-5731d3730395')])]
#  [list([]) list([]) list([])
#   list([UUID('49dac624-7ec2-4b9a-b9d8-ea4f74af5936')]) list([]) list([])
#   list([UUID('895999a8-3ff4-4fa1-aa52-a99c16875545'), UUID('63fecc0e-5879-4c83-b933-c54ab476c7e3')])
#   list([UUID('8b6817ad-d484-43af-a3d8-14c3f969d4b8')]) list([]) list([])
#   list([UUID('e59f13b9-459d-427c-a0d5-6be7ec83884e')]) list([]) list([])
#   list([UUID('df6404e2-35db-4e81-a0b8-0c187e957965')])
#   list([UUID('6a1d99e5-b613-4d28-9a81-329bc81c3dc2')])
#   list([UUID('96393ed1-67ee-473e-8fb7-0435806ccfd1')]) list([]) list([])
#   list([]) list([]) list([]) list([])
#   list([UUID('9d99cdb8-1e54-4b83-9b33-a26c054f7c45')]) list([]) list([])
#   list([])
#   list([UUID('c5cbaacd-33e7-4342-b45a-bdbee264e92a'), UUID('e8648218-7151-4055-adfd-a5c499f26f3f')])
#   list([UUID('8582b297-9242-44ce-99b3-e9e8fa1f656e')]) list([]) list([])
#   list([])
#   list([UUID('2f0cc9f5-95ce-4fd5-8a8f-3abe331be251'), UUID('d9e76646-19a9-498a-a527-ec28240e163a')])
#   list([UUID('d65eb764-e58f-422f-83f0-619aee81f57d')]) list([]) list([])
#   list([]) list([UUID('26948681-483f-461b-924d-40dc83be2d13')])
#   list([UUID('2ffae5c1-c8a4-40ce-a19b-99c336c9d8fc')]) list([]) list([])
#   list([UUID('ce8e90a1-b693-4d97-85bb-e52efb1d6eb0'), UUID('378af28d-c31f-4fac-9c2d-3548822cf507')])
#   list([UUID('654fd3f6-f8ce-413c-a2e1-15ceca3f8ead')])
#   list([UUID('88a41ced-156f-43dc-bb84-3116964dc704')]) list([]) list([])
#   list([UUID('d717760d-ee45-4178-8df0-96c1d028a80e')])
#   list([UUID('2e6e0bb4-d59e-4909-9707-110f01d9b780')])
#   list([UUID('f0f17276-8101-4b6b-932e-c8a0e12a88ee')]) list([])
#   list([UUID('a4d0c061-f135-4219-8d61-2d58cfc13f00')])
#   list([UUID('6bc4f625-141a-43bd-845c-11c3d031511c')])
#   list([UUID('f39e916d-fc1d-4332-8d83-4b0d6437f1a4')])
#   list([UUID('26c43ae2-fba5-4d5e-bbf9-db57ae31320b')]) list([]) list([])
#   list([]) list([UUID('77b99d40-8da4-4791-87ca-f07f60cea295')])
#   list([UUID('dd0fe7f8-48d3-4565-a822-e6c3c1f7e5ec')]) list([]) list([])
#   list([UUID('58487b6b-9143-4632-92b7-b3f76c2ae70f'), UUID('7fb77368-afff-420f-8d0a-5e5a9225ecf0')])
#   list([UUID('f59b6856-e62a-4b27-b4f3-c7439e239831')])
#   list([UUID('6477db3f-83e3-4db0-9353-ef14aef31120')])
#   list([UUID('c34a8eb6-c77c-408c-8a84-d8119db4daf7')])
#   list([UUID('1371925e-c627-42af-a38c-482263d94710')]) list([])
#   list([UUID('326e371e-d783-41ab-a9fa-9323091791d2')])
#   list([UUID('52a95b77-f7e0-4935-a6a3-b8e4fb977a70')])
#   list([UUID('2cd1a602-c750-47a2-8c76-5f3adb93a0d1')])
#   list([UUID('980343f6-36a8-46e0-967c-e71a12d50194')])
#   list([UUID('d82c754f-98bf-4668-9676-a06d9c6be757')]) list([])
#   list([UUID('c25d4072-c7f4-45eb-bbf3-e39cf6dc6d69')]) list([])
#   list([UUID('d32c1fe3-421e-4278-bc6b-bf35d7b0702e')])
#   list([UUID('5ad0cfba-3075-4558-98fb-0f4181c627bc')])
#   list([UUID('ec827ddb-d405-4550-8918-88ce1c31d7ce')]) list([]) list([])
#   list([]) list([UUID('46eb0438-f246-4742-ad7f-14a1fdc2b977')])
#   list([UUID('b3db525d-17f2-4549-85af-03c8c92da5f7')])
#   list([UUID('ee73c9e8-a87b-4a76-b860-261f6b1b6c21')]) list([])
#   list([UUID('7eb91541-1995-4864-899b-ba376b4b7c34')]) list([]) list([])
#   list([UUID('2b62dde7-acd8-40f7-989e-2e9eda15c0b1')])
#   list([UUID('82061971-07e4-4373-a803-43ce3431a350')])
#   list([UUID('f758342d-7b04-4c8f-9ede-6de9dc683b2f')])
#   list([UUID('5f608ec5-927a-4c28-b359-57ee556d9973')]) list([])
#   list([UUID('c400074a-1ede-4ce9-a5c0-cfe7d585f6a5')]) list([]) list([])
#   list([UUID('519ee8a6-3bb8-4480-88b1-d444eff42ad1')])
#   list([UUID('e599100c-16af-4cde-8eb8-ce91b9bd17ff')]) list([])
#   list([UUID('a90d98ef-18ce-4c86-bd13-9464f5ffc89a')]) list([])]
#  [list([UUID('5d251244-65e8-4808-9549-05e7967f6d04')]) list([])
#   list([UUID('5d5bce36-62ac-4cbb-91ec-6d1e21ab2307')])
#   list([UUID('96928e37-8557-4f0b-9d6a-54ea744c8097')])
#   list([UUID('d0074276-f0a6-4204-807c-956f33babd71')]) list([])
#   list([UUID('b7cdd8bd-8b8f-40fa-83fd-70e8e343ad0f')]) list([])
#   list([UUID('ca60e6d7-e545-42d0-a8ec-b5fa41e05d95')]) list([])
#   list([UUID('2a5cadd0-3b44-4f5d-bc2e-b09907f82625')])
#   list([UUID('59101eb4-8e30-43ef-9b6f-70ca86a1e8b1')])
#   list([UUID('34726dac-fa06-4400-99bf-50a29470c44c')])
#   list([UUID('cec42cb4-9d30-469d-9973-c12d6e92ec73')]) list([])
#   list([UUID('50e16be4-a1cb-48db-9f14-2afbec2068d0')]) list([])
#   list([UUID('93154cf8-ea2c-4faa-8a17-11b7aefe5f81')])
#   list([UUID('a79bc41f-0165-4ceb-8656-fb18f5a6bcb7')]) list([])
#   list([UUID('3d893feb-551f-4d4c-94a3-368a509806c0')])
#   list([UUID('3eaeeee6-fb53-43d7-9f1b-bd7f1643c834')])
#   list([UUID('efdc3094-7e84-45de-97cc-a174611f8383')]) list([])
#   list([UUID('492cb02c-b5d3-4889-8044-c7cb6c44310a')]) list([]) list([])
#   list([UUID('5338ff33-d3ff-416a-866e-3445c89e11b1')]) list([])
#   list([UUID('ecaca7ac-d657-4b26-90c5-748bada15971')])
#   list([UUID('a8717b2e-1f75-4b8d-8673-69122a420200')])
#   list([UUID('6d014b91-bdd8-46b6-b7e1-1b0cffd3916c')])
#   list([UUID('4a93886b-cf96-411a-b2da-ce85fae45d3d')])
#   list([UUID('5aa2fd8e-8a18-4bbc-8450-edd3126f905e')]) list([])
#   list([UUID('5e10d179-9b5f-4c33-9cf2-b5d84a521770'), UUID('f43aef51-5b74-438d-9cb2-5844d7bc85f6')])
#   list([UUID('efefcf54-4d2f-44f8-b7f7-162a5300b7ef')])
#   list([UUID('5c73e466-38bf-4c8b-80f1-f0efa3f4a4a1'), UUID('e15c75ec-0a07-4819-a29b-215726242ec8')])
#   list([]) list([UUID('11f43b90-f02e-476f-895a-1e6e31ff1023')])
#   list([UUID('759adcd0-1077-4a3a-a708-3b15062188a6')]) list([]) list([])
#   list([]) list([]) list([])
#   list([UUID('ca62d32f-768f-44b7-8091-ec75e7f1f478')])
#   list([UUID('a3b352ea-287e-47b9-9381-38ecd9fe9e0f')])
#   list([UUID('17a31464-3a61-41f3-97bd-943579923d26')]) list([])
#   list([UUID('90c42322-7431-4e89-bc7e-3366701aeda2')])
#   list([UUID('c4895811-883d-4cc6-8b69-dbae6a2baaab')]) list([])
#   list([UUID('c08a93ca-f113-42eb-a26d-d6155a0baaab')])
#   list([UUID('16db080a-c89e-47cc-b083-69fcb22eb731')])
#   list([UUID('1868687e-a6fd-4887-91e7-1423b4d56cc0')])
#   list([UUID('4ddc847b-f05a-45b0-878b-a20538c140b2')]) list([])
#   list([UUID('f2f4dea6-2d63-4502-b1f8-8b7e27aaddea'), UUID('142997ee-0080-406f-900d-8c26f006138b')])
#   list([]) list([]) list([])
#   list([UUID('79ab8365-e276-486e-81e0-7367999f25e9')])
#   list([UUID('a33aac6e-9ea9-4a22-8c89-8bfa9d8aa77b')])
#   list([UUID('e897eae6-375d-4c1a-80f3-2f4466b3a78f')]) list([])
#   list([UUID('faf1444a-77e4-421e-bf7d-6bc361317d10'), UUID('1f9e945a-d99e-4eab-bf83-e77f978c6521')])
#   list([]) list([]) list([])
#   list([UUID('c837cd16-2ab8-4db8-90b2-b19f94f3b6a7'), UUID('781552e8-bfb4-4b6c-923c-7a6770eb5f83')])
#   list([UUID('8ebb5a02-0ee8-469a-8522-4ee0fe8c594f')]) list([])
#   list([UUID('ba0af8ce-83c3-418a-a2ae-3d7b6f4bf449')])
#   list([UUID('0169b721-fa11-4843-a90d-69a1ea19ac53'), UUID('4e1578e6-0069-4ad4-a710-a6944b8c0797')])
#   list([UUID('8ed31a01-b9b7-4b96-b2c2-47543060278e'), UUID('e0b0088e-3157-47fa-9897-86849df0f15b')])
#   list([]) list([]) list([])
#   list([UUID('0bc7f0bf-dd6e-4b03-8e1d-2b2428d23c99'), UUID('5c303d89-e3b3-4a67-bb14-bfdfc426daa8')])
#   list([UUID('2392d383-17c4-4f32-92e3-f404e71af2ff')]) list([]) list([])
#   list([UUID('2cb36eac-4bd5-407c-8439-af1901a7cefb')]) list([])
#   list([UUID('7ac9a0ef-7c2a-48ef-8887-0fe48f8052cd')]) list([]) list([])
#   list([UUID('3ce2b91e-8a3b-479c-9e52-242146d3103d')])
#   list([UUID('150bd022-1df8-46d4-b0aa-4f8ef579075a')])
#   list([UUID('fb177ea1-7294-463a-819b-d39f5a3107c2')]) list([])
#   list([UUID('b6dbf4ec-f713-4b8e-b4bc-29a7601a7b46')]) list([])
#   list([UUID('108558c7-859d-4986-ba53-a70da3f5b4c4')])
#   list([UUID('356cf1a9-b843-4320-8436-719672fff0cf')])
#   list([UUID('ee3df540-0d4f-47e4-8487-7e658b1e90c5'), UUID('bedc688b-a2af-45ce-b149-52c43c6fc4a5')])
#   list([UUID('f4fc7b6b-637c-4ce1-8c73-ecaf9909a1bf')]) list([])
#   list([UUID('bf31c2db-f294-4e6b-8cee-8a801ea7d07a'), UUID('502e190c-76dd-470d-bb3e-9d80fcd4aeb5')])]
#  [list([]) list([]) list([UUID('14701290-17bb-4b0d-886c-07a188f9de9f')])
#   list([]) list([]) list([]) list([])
#   list([UUID('ef181c95-8ba6-4e88-92e0-6a7197b1cfbf')])
#   list([UUID('d7bd798f-fa14-48ff-afae-bed045048b39')]) list([])
#   list([UUID('8acc09aa-5cd6-4373-b11f-8a865bf60c81')])
#   list([UUID('7e9d9b09-1f94-483b-b6fe-f1f47a759777')])
#   list([UUID('9adc6061-a783-4565-946b-afba368fb686')])
#   list([UUID('48099aed-4bac-4f1d-9057-5fd68f152dc3')])
#   list([UUID('29cbed56-5fc2-4628-ad2d-294ebb4caa9c')])
#   list([UUID('f9b9529f-485c-4b3b-9895-e406d8d1b57b')]) list([])
#   list([UUID('83c22640-74a8-417e-bf93-5bb989eab5fc')])
#   list([UUID('07d7229f-dc12-456f-8409-f91e1ef96227')]) list([]) list([])
#   list([UUID('8e64db01-46e5-49a5-ae74-b4e3e53b1b8d')])
#   list([UUID('4ad88c77-7ad6-4b2e-aa82-1c387d097ff7')])
#   list([UUID('8f16dfab-c1cc-4e26-ba2e-0e0e7d1cb998')]) list([])
#   list([UUID('e90c29a9-d279-4549-ba1d-bddade000f3e')])
#   list([UUID('8d5523c0-63c5-4872-8cec-28be257d2471')]) list([]) list([])
#   list([])
#   list([UUID('35933d19-5dc0-4d3a-808c-6a3b718b9b8e'), UUID('1cd02f0c-2ac2-4235-934e-8e0068cad5fd')])
#   list([UUID('e743d570-02e9-43ff-bf57-8ee356b5a732')])
#   list([UUID('393e85d5-5ddf-4d1d-9b1a-354f6d4afd09')])
#   list([UUID('3cd8f8fb-1600-4ddd-8719-6f8350ba322c')])
#   list([UUID('0b7bd16c-f415-44e4-b943-c5f7c1db1abc')])
#   list([UUID('c1c0c1d5-7112-4b23-aae9-7e40e9947d73')]) list([]) list([])
#   list([]) list([UUID('3d5bf4cd-1525-4be1-ac7b-459e90140d2b')]) list([])
#   list([UUID('ecdef9d6-be7e-48a0-b009-487f0e176cfa')])
#   list([UUID('60d74eb4-a17c-4da2-86df-cb5ddb2ab562')]) list([])
#   list([UUID('c5f860d7-4940-405d-8a8f-f6df3471dff4')]) list([]) list([])
#   list([]) list([]) list([])
#   list([UUID('4fe40686-bfc5-4898-9c80-d0f8188d3420')])
#   list([UUID('8fba6e4a-7dfd-4fdc-866e-7ca8884bacba')]) list([]) list([])
#   list([]) list([UUID('5df24050-e3ea-44f8-a46b-96d9f5e262b8')])
#   list([UUID('3a84d5ec-d1a7-46a9-84aa-235bab4eb011'), UUID('f68fe30e-9e3c-4db1-8714-2ec4b5ea8f95')])
#   list([UUID('d081aee2-e740-4dcd-b8db-6fce9173654f')])
#   list([UUID('01fe8db5-d3c5-418d-ad81-ad09fd799a5d')]) list([])
#   list([UUID('c017c71d-dc3f-49a0-852b-eff5db627885')])
#   list([UUID('bae0e9a8-a4bd-4ab4-9bad-2e38524ed7c4')])
#   list([UUID('b0d87c25-ac32-4ded-a43a-70909273598b')])
#   list([UUID('297670d1-a9b9-46a8-a855-c20f5f355a58')]) list([]) list([])
#   list([]) list([]) list([UUID('bf73922e-04c5-42eb-a832-a12dd5da1ff8')])
#   list([]) list([])
#   list([UUID('72729102-680b-48f1-8b3d-e3195b8b3966'), UUID('29da6769-83d7-49f0-816c-6f9deecd3709')])
#   list([]) list([]) list([])
#   list([UUID('53910962-d85c-4be6-b8c1-9da0ce1b4430')]) list([]) list([])
#   list([UUID('64d110de-fb00-4782-a88a-79c9a93eab0a')]) list([]) list([])
#   list([]) list([]) list([UUID('01d938e4-5c9c-4670-935e-b20e13e9468f')])
#   list([]) list([UUID('94deea01-7487-415d-8c18-c622143d0c61')]) list([])
#   list([UUID('d093bee5-e580-4430-b91c-2c95f481dc37')]) list([])
#   list([UUID('8a9802b6-5432-4945-a031-4630b8c2a3ed')]) list([])
#   list([UUID('0b1a05bb-7c1d-43b1-aa5e-53faafeafe4e')]) list([])
#   list([UUID('4cf324d6-036d-4727-baee-093a2cc23101')]) list([])
#   list([UUID('f2137130-90c1-4cf2-a072-6a515f24d822')]) list([])
#   list([UUID('55071594-cd2c-4e1e-9b37-e25f1ce4bf03')])
#   list([UUID('c91313e0-57b0-4121-95a1-f7870ea2853b')]) list([])]
#  [list([UUID('13de31ff-3b25-4434-a347-810bbf0f302e')])
#   list([UUID('835e58d5-9efc-4923-ad2b-daafd8e675f4')]) list([]) list([])
#   list([UUID('682f22f3-8bdb-47d7-b56e-3adc8e82d490')]) list([]) list([])
#   list([UUID('6454c884-87fa-4739-9aae-4967de4bcdb1')])
#   list([UUID('32927e88-e4d6-4ee8-b3b5-e04c5c242388')]) list([])
#   list([UUID('b7a25064-7f21-46c2-816d-8d7a990d64d0'), UUID('c2eff7b5-6dd6-4154-aa7d-000690756330')])
#   list([]) list([]) list([UUID('09cde9f4-f522-452d-9606-21f91509d549')])
#   list([]) list([]) list([])
#   list([UUID('7323341d-2dc9-4e42-a013-079735be95f8')]) list([])
#   list([UUID('77800381-47e3-485c-9af4-22cd674457ae')])
#   list([UUID('dec74808-7533-4b25-9058-24aa6de03de3')])
#   list([UUID('59fd8207-13a6-4353-be24-b0c19e1cf03f')])
#   list([UUID('9242d0cc-2115-4ced-b63d-207d64e51c69')]) list([]) list([])
#   list([UUID('665d2333-4ae0-41be-b94f-5ecf451c048d')])
#   list([UUID('50b268e5-8de2-4287-865d-971e140ddbd0')])
#   list([UUID('17c67e47-dcb7-45c9-a20e-113e7764a350')]) list([])
#   list([UUID('a8b35801-8605-4c68-bb07-b8bbd5d89a9a')])
#   list([UUID('977d4a3e-86ab-41a6-a938-8efa2d771635'), UUID('fcf3f17e-e53a-40f5-a137-1ff815056484')])
#   list([UUID('f4618a85-0a23-4960-ae34-b6be0b829036')]) list([])
#   list([UUID('a8bd2d70-4432-414b-a099-6c8dd145de89')])
#   list([UUID('f7d513e9-13d8-42b4-9191-24ffef97a7cc')]) list([]) list([])
#   list([UUID('4b7c428d-e82f-4be4-8795-fcb5aec33f6a')])
#   list([UUID('91fd5635-3a11-4837-8ae4-2298da749954')]) list([])
#   list([UUID('886bf967-18ee-45ad-bba5-70b161d4e8a8'), UUID('bd2b4e3e-7554-4841-9d78-6d5e1b732d24')])
#   list([UUID('775815fe-2f4f-4c3a-ba27-dd890e4cfef0')])
#   list([UUID('dd761a9a-9b85-452f-94c7-b5e7c3a46102'), UUID('f3430670-2b5a-4eb4-8cde-c5d55c64bd6c')])
#   list([UUID('0b289ec1-b42b-48dd-be44-17734c891d3f')]) list([])
#   list([UUID('9bc6ac56-f8ea-450e-8cdd-b0d36b730c35')])
#   list([UUID('d0be5fd3-f935-4b4d-b8bd-37afeee59bfa')])
#   list([UUID('aae6fa86-ce5d-4145-b825-7df98f92d336')])
#   list([UUID('d634ad66-2b94-497f-8c97-bd39b6d3ce60')])
#   list([UUID('bec6ce64-fc3f-43e4-911e-969a37257e42')]) list([]) list([])
#   list([UUID('8a515a3e-58ab-4924-a518-90dace4abc49')])
#   list([UUID('6b9e349f-59c6-4961-968f-e1b2f1ea8ad5')]) list([]) list([])
#   list([UUID('7ba96425-568f-4790-aeb5-c91e2d7dd591')]) list([])
#   list([UUID('6fb4d0e7-494e-4795-9f28-e7f357e8fa3c'), UUID('02125f64-def5-4019-a289-42d2848aeec6')])
#   list([UUID('b7abae50-cbf4-4af8-a6bc-567bad95b594')])
#   list([UUID('84d08a04-975d-4419-8ffa-9a3d3245d086')])
#   list([UUID('bc595918-8773-4092-90d6-e8cdde4b207f')]) list([]) list([])
#   list([]) list([UUID('06871605-7ccb-49c5-aba9-ea60a71cd8b0')])
#   list([UUID('e76275a6-af8f-45a6-a390-29985f2eba03')])
#   list([UUID('d8ae9893-7ae8-42f1-9655-2539176210f4')])
#   list([UUID('ba34a38e-fd92-429a-9ee1-06f26c266742')])
#   list([UUID('50c71974-74aa-4c35-a185-1f5419eaf73d')]) list([]) list([])
#   list([UUID('e5786c7f-73fb-4ef0-b5c6-563ae2a6f845')])
#   list([UUID('b3319948-1de0-4776-971c-6b066903302d')])
#   list([UUID('c0d6edd2-f0dd-4b2b-b98b-4382ad4c7e6b')])
#   list([UUID('f1a2edd6-f1ed-4f46-bc7e-5cec664715d6')]) list([]) list([])
#   list([UUID('511dc22c-c908-4650-b9d7-9a36156da57f')])
#   list([UUID('c253ecd6-eaf3-496f-ba42-577449717ab8')])
#   list([UUID('6e731cce-563d-4441-a536-4d89bc0dc305')])
#   list([UUID('fe07e4f7-9097-4bcd-9a03-68389faa4346')])
#   list([UUID('b92650cc-6434-4dce-86a3-28a88d3a1f6d'), UUID('e89fdb3a-9544-4286-b71d-ce925d13d76c'), UUID('f7799d3e-eb06-4d20-8555-38cf688845a2')])
#   list([UUID('e8549d5e-f2d5-44f8-9a1e-9e13394ea8a6')]) list([])
#   list([UUID('7edee160-6524-4f56-8e7e-097f96dbdcad')]) list([])
#   list([UUID('0f7ae584-6dab-4630-8fc8-09e81dd59bf5')]) list([])
#   list([UUID('3aed429e-5436-4c4c-b563-dc3d6cc9844a')]) list([]) list([])
#   list([UUID('9158f698-b868-4821-b6c6-740ee2300551')]) list([])
#   list([UUID('c002fa02-4d51-448c-9ca3-7a907cd2d38f')])
#   list([UUID('7cd05343-052f-4ab3-a11f-34f42723e46d')]) list([]) list([])
#   list([]) list([UUID('46a4a870-8ef0-4610-92a1-25c63c69b2f4')])]
#  [list([UUID('14b9b81c-b727-4105-897f-d9ced5e38d70')]) list([])
#   list([UUID('aa336e19-6e69-45be-a093-2a9819c2955b')])
#   list([UUID('b9269ef9-4f6d-4701-8089-b0ed367a5e76')]) list([])
#   list([UUID('d4b547ea-28bd-403f-ad5e-79475ee0317e')])
#   list([UUID('26a0e532-44bb-40b5-b02c-0db717d70363')]) list([])
#   list([UUID('96ac5531-b5e8-4d76-b8c4-8dd51395186e')])
#   list([UUID('e7aabd1e-059c-494e-b5b5-1e32c50ab81c')])
#   list([UUID('6d9a9258-5c75-4de6-a1b1-35aaa4d2c547')])
#   list([UUID('42471acf-f0ac-4492-a7e2-42396260f2d5')]) list([])
#   list([UUID('4cbf399c-b6cc-4718-92d9-93aab5877cd4')])
#   list([UUID('72477731-63b5-4a7f-87c3-b47fc218a5a3')]) list([]) list([])
#   list([]) list([UUID('a9d2659d-f01e-4b5f-b960-7072f65ef214')]) list([])
#   list([UUID('9bd5f61a-5d18-47c3-926b-7640ea3ebac6')])
#   list([UUID('ec2c497d-4f86-4480-b474-ea77b1bc0208')])
#   list([UUID('c568bb66-ebcc-42db-82ce-3a90fccf7525')]) list([])
#   list([UUID('e7562afc-3bf7-4a9e-b019-efe6351301ee')])
#   list([UUID('59482a79-cbdd-4d50-9d44-0d2c400ce62e')]) list([])
#   list([UUID('1e175edf-04ac-428f-92c2-02ef6cbd69c3')]) list([]) list([])
#   list([]) list([UUID('2f0fbd6f-7ea9-4217-8472-0b253a6d3fca')])
#   list([UUID('f6e90c68-65eb-43c4-b271-48714adb8cb4')])
#   list([UUID('43b222e8-c4a8-4bd7-bcf7-86bf39576fd8'), UUID('c02abfbc-467e-4477-916a-ff167df946db')])
#   list([UUID('b8340869-2e1e-4652-9121-32577be9dbda')]) list([]) list([])
#   list([UUID('640e5d81-583c-4d19-8121-29a275ebe9cc')]) list([]) list([])
#   list([UUID('ed36da23-686d-423d-b531-d327966fc300')])
#   list([UUID('9e09cea6-6b7a-4728-8286-c35dac8691e1')]) list([]) list([])
#   list([]) list([]) list([UUID('7d2da4d1-1b4f-46d0-94f1-79784a793ab9')])
#   list([]) list([UUID('e59ad374-2968-4a73-b575-e636a01b6197')])
#   list([UUID('45924084-0743-4e5d-971d-233fa6f4ef8d')]) list([]) list([])
#   list([UUID('960fe5ff-f7e5-49f6-883a-ea901b1d952d')]) list([])
#   list([UUID('97f21c02-b78c-4c6a-898c-e9a9bec5e5b4')]) list([]) list([])
#   list([]) list([]) list([]) list([]) list([])
#   list([UUID('3bfa637a-6c46-46e7-8a60-c49c5d19488c')]) list([])
#   list([UUID('c2efeef1-ecc0-475a-ad8e-328a38560200')])
#   list([UUID('face2d1f-bd60-418a-ba0c-d550824366b8')])
#   list([UUID('17d6fc64-8e4b-42c8-b344-f7aff56b06ce')]) list([])
#   list([UUID('226d731e-775f-494c-913c-976e013a1af5')])
#   list([UUID('06f22ac5-c5e8-4997-be0d-e4e4f8fb539e')]) list([]) list([])
#   list([]) list([UUID('5a1892f3-081f-4164-bf10-d69f0210139d')])
#   list([UUID('a0b0915a-f53b-4ba0-bc26-ef4643c58838')]) list([]) list([])
#   list([UUID('40fc7632-8a27-4173-aaff-8ca0cf5dd786')])
#   list([UUID('65eedb72-d097-4030-b639-c19c3dba5a2a')]) list([]) list([])
#   list([]) list([UUID('e68c23e4-08e8-4fc6-a552-25d3f3d34c5d')]) list([])
#   list([UUID('15dd456f-1c18-4331-8c03-4d0a4e47a923'), UUID('da3465b4-a908-49d4-9bc1-9bdb49355e3d')])
#   list([UUID('7c5c8bfa-ebd4-43e0-a013-4ae7138db960')])
#   list([UUID('b32f3f2f-589c-4034-83ed-4245d99cd996')])
#   list([UUID('d36efe6c-00e1-4136-b748-7eebfc3bbb28')])
#   list([UUID('30d71309-b393-4dcd-bd9e-6e5e25e801d4')])
#   list([UUID('a7e7739a-7129-4233-9b01-7b788dbe7960')])
#   list([UUID('d7527519-72c0-45c4-b5dc-7890e1c3a3b1')]) list([])
#   list([UUID('d92ea2ae-b124-4ddb-a91d-f80080722701')]) list([])
#   list([UUID('9501bdf2-3be5-4697-8320-3cd659b5c086')])
#   list([UUID('488ed692-5e63-479b-92e1-6c47755620a6')]) list([]) list([])
#   list([UUID('7a98f60c-a0ac-4c31-a28b-38a1bd758244')])
#   list([UUID('941ce41a-a5cd-43d9-9b0a-c2ffc80e37b4')])]
#  [list([]) list([]) list([UUID('595e7411-5aee-4abf-b1ae-7afe3220cb71')])
#   list([UUID('e0c75753-f5a2-469e-ae1f-9e89205b1ed7'), UUID('14bde0d5-225e-4050-abde-d6479eb4374e')])
#   list([]) list([]) list([UUID('9743efb9-d984-4768-9b7d-cfdb2bbaa311')])
#   list([UUID('13b0183e-37f6-4d44-bb3f-4895844a790e')])
#   list([UUID('d1e7d5e1-0679-48e2-b48e-ebe4dd016171')]) list([])
#   list([UUID('8a15b457-f092-43d7-941d-4e842dcb3807')]) list([])
#   list([UUID('f23f2bcc-36a6-4940-9d2e-082198447983')])
#   list([UUID('1ca429cd-79e3-4675-8014-3d3f25445b3f')])
#   list([UUID('a4360170-48ec-486c-b792-1772cf117138')]) list([]) list([])
#   list([UUID('c1f33703-7095-4907-8918-b6b9208c189d')]) list([])
#   list([UUID('71bce0ce-5615-4e17-a225-ed11405ae943')]) list([])
#   list([UUID('80bfc2f1-ef19-453d-a854-02a707fa692a')])
#   list([UUID('d73385c0-f5fa-4464-9e4b-31809706652b')])
#   list([UUID('095051f7-0f43-426b-90d7-fa5342ea3848')])
#   list([UUID('e18d5669-6e0b-4010-b4c0-1483696c26a0')]) list([]) list([])
#   list([]) list([UUID('153a611c-adac-44b2-9fae-6353501a8b85')])
#   list([UUID('7f3aefde-db73-4282-9aa0-678a95406fa1')]) list([])
#   list([UUID('b8987ad2-16d8-46da-bb77-7395bb3cc970')]) list([]) list([])
#   list([]) list([UUID('ba252a5a-5212-4f72-8509-939d503652cb')])
#   list([UUID('5c460b51-8c79-41eb-a8ff-0deda958abcd')]) list([])
#   list([UUID('f0a3211f-338e-4e4f-b3da-09115dbf7dda')]) list([]) list([])
#   list([UUID('70d68086-d9e6-4f90-ae55-eb5404ab7109')]) list([]) list([])
#   list([UUID('b76de783-6c9e-4cbd-b8d5-64a7bd6471e3')]) list([])
#   list([UUID('54b46f9f-3cb4-4d05-bd07-07ad6356313b')])
#   list([UUID('ea16c6bc-207d-4255-857a-d15a47f74901')])
#   list([UUID('8cca38a8-113f-4265-af4a-ef37d79263b9')]) list([]) list([])
#   list([UUID('ae86e321-be7d-4564-96b5-1850a44e7f37')]) list([])
#   list([UUID('1301ed20-1895-44db-aafd-dd43aef0b6cd')]) list([])
#   list([UUID('71726972-2931-4b76-8f47-e646747e489e')])
#   list([UUID('35d04dd1-a355-40a0-b0c5-cdc7287a35ba')]) list([]) list([])
#   list([]) list([UUID('4cb26610-33ff-4d46-af14-d2d6cc7d6c77')]) list([])
#   list([]) list([]) list([])
#   list([UUID('026ac80d-6bdc-4fd0-90fe-fbc66ca833d8')]) list([]) list([])
#   list([UUID('a2c01519-76de-4c1f-9fb3-62e6fbe47688')]) list([]) list([])
#   list([UUID('0ffec3f5-2627-4d20-aad7-0caea4cc4381')])
#   list([UUID('4ff410a6-e5a0-4325-93e4-9b2c62ce4bbb')]) list([])
#   list([UUID('ca9e7942-c2f9-4a75-ab05-86a65c6c0898')])
#   list([UUID('15e87a0d-40f2-467b-9fce-46d300d83463'), UUID('ed83d82d-5957-4f5b-8f56-73abcc08fead')])
#   list([UUID('b7b1d14a-6137-41f0-94d8-49207d3ebdca')]) list([])
#   list([UUID('1e98f420-6976-44c7-83d7-4e0e9dd71bc7')]) list([])
#   list([UUID('2d9df4cc-6b08-4e9e-9466-82878fed98d9')])
#   list([UUID('ffe5b278-f950-462d-9090-4c081638da42')]) list([])
#   list([UUID('f77f7e2f-47f4-4d29-8daa-736f3ebe100a')])
#   list([UUID('974dd706-d6aa-41f2-b0b6-8748ce4fa5d3')])
#   list([UUID('fb335311-e4ee-4a7e-9a66-81d73eaecb4b')])
#   list([UUID('cec783f7-97db-497b-a077-ad2e5445f243')]) list([])
#   list([UUID('5bc318b7-2941-4070-a7bd-b7bc7c3283f2'), UUID('e1faaa6b-e215-4e4c-a9fa-ef31eab83de4')])
#   list([]) list([]) list([]) list([]) list([]) list([])
#   list([UUID('8fca36a0-3bf4-4f37-88e1-3198d3de8ba3')])
#   list([UUID('59b56895-8a4e-457f-a97b-e4451c0d5515')])
#   list([UUID('2eb76656-65ea-4f15-9900-502a6cbf23b4')])
#   list([UUID('8938c3a4-0d42-4474-9eb7-bd1c2f9bd65a')])
#   list([UUID('01b8a694-26b5-4321-bc94-6bcadf985fa4')])]
#  [list([UUID('e7831a2a-0365-408a-b89f-ef01234de37a')]) list([])
#   list([UUID('e01257c2-bed8-4e7a-8eba-98c148147ace')])
#   list([UUID('b9dd0336-7f49-4ca2-89cf-3cb2e49feb57')]) list([])
#   list([UUID('89b8e5f8-c7b7-41c0-b72f-5e1f3c4bbb7d')])
#   list([UUID('be115f05-c69e-4884-b5fd-3e7803daa3a3')]) list([])
#   list([UUID('6b19e0dc-1bc4-4cd4-baf7-1a54d2391aaa')]) list([]) list([])
#   list([UUID('b97f4c70-9eea-4d7b-ae42-78b2d7596942')]) list([])
#   list([UUID('8c08927d-62fe-4e1d-b229-2b5a55011ee1')]) list([]) list([])
#   list([UUID('e75efc5d-1265-4fb3-9bf8-0cf630ba1af3')]) list([]) list([])
#   list([]) list([UUID('ef71a7ae-43d8-4925-b36a-38dd3e8f4f6e')])
#   list([UUID('d4872eb5-3db3-44df-9b45-52324f99d9c9')]) list([])
#   list([UUID('917ac069-b52e-4afb-a7fb-4a3075cf3480')]) list([])
#   list([UUID('ff6f0654-17c5-43dd-9bcd-73dc010e22f5')])
#   list([UUID('5d1ea055-f1f1-44ff-93cc-62c5c069b4db')])
#   list([UUID('27e23005-e640-4239-8745-b8ad7fa57fa6')])
#   list([UUID('ad01e3a4-269a-45f7-851b-096ddb318f80')])
#   list([UUID('1908d760-f043-47e3-8ae8-4fe12d3dbd09')])
#   list([UUID('ff3e7b5f-54d9-478e-aa40-2d60fe229f6e')]) list([])
#   list([UUID('2044e088-64c2-4b8d-b6e0-d30e74f558a8')]) list([])
#   list([UUID('bd0276fd-af8d-46f5-b2e1-57d6589f9f25')]) list([]) list([])
#   list([UUID('e1481960-62d7-406c-9801-37c05664637f'), UUID('62fa6f03-1944-491e-9322-b0a43d42cc92')])
#   list([]) list([]) list([UUID('d29a06a3-23b8-44ee-90c9-e187fe0040f0')])
# ...
#   list([UUID('906e946b-5251-47fa-a0da-5a6236ccbc92')]) list([])
#   list([UUID('836fc8ee-5085-44cd-950a-240c5bdde9a0')]) list([])
#   list([UUID('8ac2ed6f-e7b1-4e0e-9caa-7e4797b3b067')]) list([])
#   list([UUID('96eee4d1-a78d-47f0-b1c0-247598a688b8')])
#   list([UUID('74081854-6868-431e-92e6-62a8a63fba38')]) list([])
#   list([UUID('8d55214d-c990-46e0-b538-cf9a72958841')])
#   list([UUID('a0ce5993-5092-47ab-aa94-248599d043e4')]) list([]) list([])
#   list([UUID('12938526-c64d-4c48-a95a-6c82899b7894')])
#   list([UUID('afe587a9-e00d-4efa-aec3-1b861a17b3fa')]) list([])
#   list([UUID('ebf6145c-d1ed-4fba-9c10-4580d6eed732')])
#   list([UUID('4e71e37c-7ae7-4627-9c66-580f2230870b')]) list([])
#   list([UUID('29ac60cf-5fa5-421b-b88a-db7e98d0bf09')])
#   list([UUID('0eaf35c7-c861-474c-a655-dd5c8ba2d1dd')])
#   list([UUID('bf65e7e6-b3fe-498b-9756-18e5d102bdb3')])
#   list([UUID('aeb4079f-fc19-41d5-87e1-7eb11cfdaf0d')]) list([])
#   list([UUID('0312dce5-5f55-457d-a4c3-a73bffcc073d')])
#   list([UUID('2b1ef4e6-096d-4410-aad2-8fb606bca770')]) list([])]
#  [list([UUID('ab48b917-f94f-479a-9e2f-acc540a16b7b')]) list([]) list([])
#   list([]) list([]) list([UUID('141a701a-aa22-4c73-a189-f760a3d4efeb')])
#   list([UUID('00f8f6a0-13fc-45af-beef-5c9f71972a39')])
#   list([UUID('a94aa789-547b-430f-8420-54bb166081d4'), UUID('bf4a14f6-e06c-459f-9ae9-c10323bdc5cf')])
#   list([]) list([UUID('313f0427-ffab-48db-a1a4-f7ee65df153f')]) list([])
#   list([UUID('babfb813-63f2-4459-9279-dbb30e91fd30')]) list([]) list([])
#   list([]) list([UUID('f5bec2f0-9ffd-4a01-bdad-88f3bf1ac4ca')])
#   list([UUID('576aface-a704-433c-907f-4c0a933e7549')]) list([]) list([])
#   list([]) list([UUID('95a66c15-95f1-4c44-be1d-7ca6ae0f24da')])
#   list([UUID('a177ad0d-17f3-40cd-b262-0248cbde715d')])
#   list([UUID('5062bfc5-06a5-42f5-93cb-674f5fdc3d34')])
#   list([UUID('12a8b358-6973-44be-9f79-9196a8072012'), UUID('9e1eafd4-bc52-48d8-8332-851106871b04')])
#   list([UUID('31364eac-48da-47e2-9b4f-2e64db640dbf'), UUID('6d207682-9754-45f6-9946-003b5444cbfd')])
#   list([UUID('3ebb72bf-9a10-4245-8ba2-03a2e0c8b5bb')])
#   list([UUID('71c2b4cd-428e-4d9d-8b6c-0f3577288580')])
#   list([UUID('f6407715-9162-44dc-8f74-ee1314bb623b'), UUID('1a689b96-ee6e-4db3-8c79-6907c8d876d0')])
#   list([UUID('57a25d49-2f21-4ef3-9360-b16b88c127bb')])
#   list([UUID('8e640d86-7068-417b-a85d-d70c09d1af24')]) list([]) list([])
#   list([]) list([]) list([UUID('a22ee065-e58c-491b-87d8-fca229f79341')])
#   list([UUID('3b975176-f3c7-43bd-81ba-28abcf7b66b2')])
#   list([UUID('97e4071d-1fcd-4418-9421-d00d5baf2881')]) list([])
#   list([UUID('f39f286a-2b55-49ad-9eba-4f3b99f96ce1')]) list([])
#   list([UUID('ec30e0b6-480a-4748-ba81-52b54f520590')]) list([])
#   list([UUID('300b3c15-35c8-4e10-9d89-e3c0819cc884')]) list([]) list([])
#   list([UUID('5c60a5f0-1f67-4638-bc92-e897794b2355')])
#   list([UUID('602f1b07-ce0d-442e-8daf-d674435a8c8f'), UUID('58564f01-e758-4e7e-8b94-2e15b321fb88')])
#   list([UUID('63eaa9cc-d307-4e20-bb95-63abdbb6a98f')])
#   list([UUID('e198ae16-c330-4265-85f1-0c2ae7b783cf')])
#   list([UUID('85dd4091-802d-4f2f-a4aa-d06c965fa74b'), UUID('a647998e-0149-4d8e-b9b6-298ed276c794')])
#   list([UUID('0c9b6ab2-d366-41e5-af10-5ec6b4711131')])
#   list([UUID('dcf06c26-0077-4200-bffd-4c9828b506f0')])
#   list([UUID('fd49b962-6bc0-436c-96a9-3bba46b3fd81'), UUID('1a4f5383-cc0e-4d16-86d0-4f6b513850b1')])
#   list([]) list([]) list([UUID('3a4316c0-31fc-4857-b8ca-fac1cae205ff')])
#   list([]) list([UUID('d33ada20-31bd-4a81-8692-e171269c88e9')])
#   list([UUID('c443e485-2e89-4641-821b-9d35cdd541c2')]) list([])
#   list([UUID('9f3269db-ed13-41f4-a4c7-97d12149b8e8')]) list([])
#   list([UUID('7a49ad83-552a-4f69-acf2-3c048233ade1')]) list([])
#   list([UUID('514d2d1e-f3fa-481d-bfa9-e5f0b3ee5f35')])
#   list([UUID('fe8fcc01-9f02-415c-8e80-10ac86fce026')]) list([])
#   list([UUID('92421634-eee6-4068-b675-d951493ac355')])
#   list([UUID('b3c87dba-012d-4113-8963-8914dfebdbb3'), UUID('4881c1a7-fd72-412a-a72e-d5aedc22ef35')])
#   list([]) list([]) list([])
#   list([UUID('8048bf71-316e-4256-b913-18065d4f1653')]) list([])
#   list([UUID('724bf5a0-467d-4654-b6ad-8474795d6419')]) list([])
#   list([UUID('35ac25f6-2d09-45bf-bcca-1f322c07784d')])
#   list([UUID('da16eacf-1413-46fd-8547-6878cb7ace83')]) list([]) list([])
#   list([UUID('6333e6a1-85e2-4bb7-a36e-1ba021ce0c81')])
#   list([UUID('1dd3945e-3edd-4c10-8afb-bb31cdce7c7d')])
#   list([UUID('097ecdf8-2606-4692-9f56-5bc1938c587b')])
#   list([UUID('b73c7063-4af7-4ee6-97ed-5798d259d4cb')])
#   list([UUID('ee29e996-62f3-4f50-966d-0cfe9eb8ca0b')]) list([])
#   list([UUID('81b74341-2a02-4610-b4c4-fcf4371a5f33')]) list([])
#   list([UUID('1e9705ab-c45c-48b1-874b-8ffe29321f06')]) list([])
#   list([UUID('9c650b85-ed70-43d9-a49d-48745dfb855f')])
#   list([UUID('f56cee70-a2d8-4255-b16b-f480b16af5c3')]) list([]) list([])
#   list([UUID('9729dcd5-eca9-4caf-9735-5fd4908d480a')]) list([])
#   list([UUID('0fe2a9f2-4613-4369-8bb6-ba68913771bf')])
#   list([UUID('8801eb49-88bf-4528-971c-82278c13705f')]) list([])
#   list([UUID('871dbb87-d4ed-4201-a007-7318f7375487')])]
#  [list([UUID('0e8fb990-abc1-456e-9865-cbe66834d47b')])
#   list([UUID('4c17ebf5-9b80-4d24-a486-9e8acc07e6de'), UUID('1afb3b10-9ad8-4fe8-9662-3dffd8e11d67')])
#   list([UUID('6af17843-e535-4568-9226-a4c60adba097'), UUID('341fdb23-7bfe-4092-9147-dc24a2ba0e7e')])
#   list([UUID('61e88007-cfe0-497f-8be9-f1667528e936')]) list([])
#   list([UUID('479a3182-da98-43c8-828b-ae6710f599e4')]) list([])
#   list([UUID('711e172c-caad-4545-988e-8bd841d227bc')]) list([])
#   list([UUID('3853c3b9-b0f7-4a92-9c1f-b9246a47af6f')])
#   list([UUID('6fd64542-5679-4f25-b247-665211a9d4e5')]) list([])
#   list([UUID('f60b14e2-ff07-44c1-993e-872e87458037')])
#   list([UUID('36aaf7d8-1dd1-40b7-a04a-6253b4865126')])
#   list([UUID('b369c06c-dfc3-484c-8c59-995e2c9a0223')]) list([]) list([])
#   list([]) list([UUID('689047dc-eabe-4ee1-b8b5-6904fae817b8')])
#   list([UUID('7601befa-a4ba-4dda-9dfb-538e5e9fd0f3')]) list([])
#   list([UUID('a4d30841-977b-4acd-a8cd-e25e5cdb556c')])
#   list([UUID('28de3aa3-eab2-44ad-92ad-4239b501c74e')])
#   list([UUID('81e0524a-266c-4f10-b89d-8ff7d1628115')]) list([])
#   list([UUID('83433567-35b0-416f-b259-5138c859d6f7')]) list([]) list([])
#   list([]) list([]) list([UUID('d63f2615-3b07-47ca-b48a-56119b67990f')])
#   list([UUID('368126f2-b633-4605-bd7d-7a7ad1b0ad8b')])
#   list([UUID('34354d9c-8808-4717-aac7-7b99002f71b3')])
#   list([UUID('878c69b4-d914-4fec-8656-c6b69bb57497')])
#   list([UUID('283e1d8b-f560-4506-9f1e-fdf6137d673d')])
#   list([UUID('2fa0f09e-894b-48bb-b025-fa4b8da79010')])
#   list([UUID('9797c98f-9bb2-4d8e-9b34-7b2d507e4c19')])
#   list([UUID('d8d16cb1-fecb-480b-8efa-efb8ce3cad0a')])
#   list([UUID('32b46e38-b997-4e2a-af53-bfa64fde10f4')]) list([])
#   list([UUID('27c2ec1f-ab9e-4456-9673-749dea46ce97')]) list([])
#   list([UUID('0f4e9a65-1128-440e-a505-aea8aab6a3dc')]) list([])
#   list([UUID('3d78c991-7b1a-4ab8-b144-1fa38cad2914')]) list([]) list([])
#   list([]) list([UUID('ef96ed9b-a929-4b29-84d0-06736f7e4674')])
#   list([UUID('3de5cdfe-ca0f-4554-99c5-a4589c1a5d35'), UUID('5c4c36f2-2a7b-4b30-bc12-9a9cf1c0f6a3')])
#   list([]) list([UUID('527a6dcf-c4d4-4ac8-8894-30b3a49ab13d')])
#   list([UUID('cd7ceac7-6211-4a68-8e7a-03c09f1f7729')])
#   list([UUID('60fc8440-81dc-4c2d-99d9-f084dd275433')])
#   list([UUID('1c61f92f-11e1-4e88-89c5-c9ad192b2e43')])
#   list([UUID('3190d56a-ecd3-4705-ad20-108a93943ade')])
#   list([UUID('ab7eee9b-dc13-4357-b900-84ac4ff08e30')])
#   list([UUID('37326d36-c426-48d8-be24-cc4d3cade279')]) list([]) list([])
#   list([UUID('121295a5-e770-4631-93c8-68be1a043712')])
#   list([UUID('de8c636a-5277-4c7a-83a3-0525bc578a49')])
#   list([UUID('2babd02d-cf7b-4d98-8cc9-4063b104547a')])
#   list([UUID('7385b5ce-969c-40f0-b96f-39847ae9041b')])
#   list([UUID('b1913f32-a105-4c97-bfbf-53bdef882870')])
#   list([UUID('9d1aa43d-d98f-46e0-b1c4-938975c1c7ff')])
#   list([UUID('a022b718-7439-4959-b1c8-280787896fa2')])
#   list([UUID('49e48b39-c781-434e-9bf3-f9e496104690'), UUID('05fd17d9-6179-42e7-bcdb-cbaaf1258e65')])
#   list([]) list([]) list([UUID('25b2b12d-1bed-4849-87c9-b2d7d43af95a')])
#   list([]) list([]) list([]) list([]) list([])
#   list([UUID('0a746014-db1a-41a5-83e0-a45531cf463a')]) list([])
#   list([UUID('a2bc5bbd-664e-4a09-b051-dc5ef997b49c')])
#   list([UUID('234baf3d-a3d8-4d70-90b4-c391c59f0722')])
#   list([UUID('36104c68-8f90-4664-827b-cb818f008336')]) list([])
#   list([UUID('23dd9797-275f-45a6-9e75-ad7e21217878')])
#   list([UUID('cabc5ece-3623-412f-b6be-72ffb065406a')]) list([])
#   list([UUID('1f67b780-cea8-4cf4-be3a-1342a87db66d')]) list([])
#   list([UUID('eee0e55a-de54-4ef6-9836-a19f24fb4c90')])
#   list([UUID('cec770b5-796b-4152-b016-98a405ebf7c0')])
#   list([UUID('9f8f774e-1c7c-44be-a8c7-bc244f02a0cc')])
#   list([UUID('8473a517-6fc9-41a2-8ca1-bcee9be06ba6')])
#   list([UUID('5107ab66-f9fb-4261-ad56-e638da27d5fe')]) list([])
#   list([UUID('041770bf-4cba-48e7-8bb1-1a47404ba843')]) list([]) list([])
#   list([]) list([UUID('0d413936-3c63-4125-95a8-1272b864c082')]) list([])
#   list([UUID('cbc20abe-4f59-4bbd-8138-d9e20f9486c3'), UUID('acff2c15-70cb-4b31-a853-8e0cce7d594f')])]
#  [list([]) list([]) list([UUID('9ac26e57-a0c0-41bd-bdd1-52d6baf73d35')])
#   list([UUID('54651831-7a8c-41bc-8328-7b2b7237d80a')]) list([]) list([])
#   list([UUID('cab779dd-bf61-452a-aad1-fc6fd8b768d0')])
#   list([UUID('ee50c5a4-056b-44a6-b642-78064b708f00')]) list([])
#   list([UUID('65d84ff5-0d69-45c7-8d6c-dd79f3188732')])
#   list([UUID('de6271bc-6aa3-49b8-a34c-ba41c0131b26')]) list([])
#   list([UUID('133dac22-d0a6-48a6-84f3-5ccdecfb6dd8')]) list([]) list([])
#   list([]) list([]) list([])
#   list([UUID('61281183-dbcc-4667-8a52-a643b60847c9')]) list([]) list([])
#   list([UUID('ed979480-6a2f-4ed9-b33d-07fe8a461b30'), UUID('c9b91a4c-0b5e-40f7-8ed9-17c17cfe5020')])
#   list([UUID('49046152-a2a4-4eb0-9b9d-0ba8c5dc155e')]) list([]) list([])
#   list([]) list([UUID('bc3f6ae0-120e-47e0-a9b2-843d344050de')])
#   list([UUID('0230e742-17b8-4504-831c-6130d004b465')]) list([])
#   list([UUID('a6ce6f51-4c7a-4045-a861-9317709d9960')])
#   list([UUID('6916c7a1-4e45-4957-ab6e-8fd6cc159693')])
#   list([UUID('f42f2d43-5060-4a0c-ae29-c38d5e6f524a')])
#   list([UUID('a0e0e9b3-9072-4447-8c4a-87d60b0ca389')]) list([]) list([])
#   list([UUID('c4aa4a8a-23c1-4274-bd0c-41554560083b'), UUID('41c73da5-8a4e-49cc-843b-6cdd579d9128')])
#   list([]) list([]) list([UUID('eb4c8a3a-fbdd-4244-b5d3-271424c72a9b')])
#   list([UUID('9d27dc7d-6654-40c4-ac7b-0874dccccec3')])
#   list([UUID('948963e6-dbef-4466-a71b-708280bf496d')])
#   list([UUID('653d5bc8-2d3c-4e6a-82c3-81b300a4513b')])
#   list([UUID('325cdb29-0aff-4135-a2ed-e40edd0de9b4')]) list([])
#   list([UUID('ae262962-fb09-4d5d-a251-f35ba876dbfd')]) list([])
#   list([UUID('2d4fd417-2a7e-4e14-bd7f-c0c3012c3cf7')]) list([])
#   list([UUID('e9bd4161-ffda-4c91-bef6-36e50054bb4c')]) list([]) list([])
#   list([UUID('1e4cff0a-7236-4d3a-9bfe-cd896d06842f')]) list([])
#   list([UUID('e665a10e-d9fb-4b62-8aab-d8bbe0261997')])
#   list([UUID('c7fc7afe-0f9d-4c64-846d-74d92f879820')])
#   list([UUID('b7c81a9d-568c-43a9-8a43-b4c2ac86e046')]) list([])
#   list([UUID('1298c54d-bf3a-47df-a4a0-409ddf32bd6e')])
#   list([UUID('64160084-0786-48c8-a60c-be343f85ae73')]) list([]) list([])
#   list([UUID('74bbc86f-00ce-4eed-bd85-bdd780f00f5c')])
#   list([UUID('eb3f1e94-f800-4e0a-ab48-6cc1bb61bea4')]) list([]) list([])
#   list([]) list([]) list([UUID('b5e34388-5c97-4966-b4b8-101cc8a44029')])
#   list([]) list([UUID('b931ecf1-b9ff-473f-a5cc-3c04eab89e4f')])
#   list([UUID('83e27bdf-cf4e-41d4-8e56-81df926acc3b')])
#   list([UUID('13f41f20-72db-4525-a0fc-8a61a22adaf2')])
#   list([UUID('7e959e6c-332b-433f-b1d1-ba941668d574')]) list([]) list([])
#   list([UUID('c936456e-c85c-40e5-8854-705019363a93')]) list([])
#   list([UUID('5b5ab933-b8c2-4059-bdab-291bb951fa2d')])
#   list([UUID('9f4045c0-fd55-470a-8f33-e842e0f660ac')]) list([])
#   list([UUID('e297e459-b02b-4600-87f4-a556946f2521')]) list([])
#   list([UUID('6bbdb9d5-4791-423e-87a9-c945c2dc67c5')])
#   list([UUID('495f2d91-51c2-4c87-9fe9-aacaad78f369')])
#   list([UUID('4199263a-a3d9-4428-ac5e-d3f672934266')])
#   list([UUID('0f9965fa-2a42-4893-978c-6fb00b7a45c2')]) list([])
#   list([UUID('3c044532-53ba-4be4-a941-b3c11c0cc1de')]) list([]) list([])
#   list([UUID('7488ed65-b925-48a6-8152-38a018e20109')]) list([])
#   list([UUID('af31ccc5-c0ae-499d-8ad7-5e9508a6277a')]) list([])
#   list([UUID('6e4a154b-783e-4fcf-9799-9fca55e09ffe')])
#   list([UUID('e2149ec2-ae81-42f1-bf21-a6631e82d677')])
#   list([UUID('46bdf7e0-ff1a-4f5f-8e19-aa7ee484bed0')]) list([])
#   list([UUID('440e6dee-ad03-4bb0-bf3e-695b184eb772')])
#   list([UUID('e1461c49-4ca6-4c79-a07d-afb9c6ad3007')])]
#  [list([UUID('aa810271-e3de-46f2-a781-6ae5f0e439ec')])
#   list([UUID('00bd0e95-811f-460c-afe6-bc32abc817ac')]) list([]) list([])
#   list([UUID('c6aca753-4b42-424d-af8d-84092128ba1d')]) list([])
#   list([UUID('b862a1a8-e8cc-4fb3-aa9c-50d7e84b69bc')]) list([]) list([])
#   list([UUID('2790f6ee-7b6d-4f63-8902-7b189e0bbece')])
#   list([UUID('99f148e5-0613-425e-8074-fabd978ed4ce')])
#   list([UUID('4413e36c-ee24-43a9-8e9e-bb7f7aef8be0')])
#   list([UUID('c35117ec-69e9-40f0-88f9-6f7f96bc4702')]) list([]) list([])
#   list([UUID('86cb00cb-c4ff-4907-9715-1b7e96ca1331')]) list([])
#   list([UUID('69d13f5f-6489-4db4-824a-5466d239c0e1')]) list([])
#   list([UUID('6c097225-243c-47ab-8599-5528fc6636a6')]) list([])
#   list([UUID('0e2a4489-5616-4443-aa4f-86bfdda9112e')])
#   list([UUID('14c508ef-fcd8-4b8b-8605-60c5fb91fa4d')]) list([]) list([])
#   list([]) list([UUID('a310b86a-4890-4fb8-860c-f9d4851a099f')])
#   list([UUID('2bf13e52-dd8c-4c2f-8009-5921af36fca0'), UUID('49576081-99b5-4957-8dbc-458ace735410')])
#   list([]) list([]) list([UUID('5c2a3fd5-0181-4673-8296-8eec8131a76f')])
#   list([UUID('eb2408f0-71da-40e8-af04-e592b99675ce')])
#   list([UUID('0c0980f8-1a45-46f0-85e0-bf4a05458148')])
#   list([UUID('b7f5d19c-913a-4863-8449-357d4794ca90')])
#   list([UUID('9a1a76b3-7f4a-4365-a0fb-0e1b7ebf693f')])
#   list([UUID('82c9441a-d6a0-40dc-87e7-8143c7952408')])
#   list([UUID('bee66569-eb66-4643-b443-723f48c904b7')])
#   list([UUID('5505a4a6-6ab4-4894-b5f8-292a0ef7a8a6')]) list([])
#   list([UUID('0036e235-c3a0-4e5a-86d8-39148ec34122')])
#   list([UUID('ad7705fe-9d33-402f-8e0b-a7f1e5d23526')]) list([])
#   list([UUID('34ee1d40-444b-48c5-ab5a-25fb969e71d3'), UUID('787d3f11-2183-4c51-add3-d3f8cc050934')])
#   list([UUID('0cb5eaa3-cfb6-466a-b8a9-0f4037b8a607')])
#   list([UUID('32e9a263-398c-45a6-81ae-c60c298133c9')])
#   list([UUID('21946065-54bf-43f0-a586-5a0b9e7f7ab8')]) list([]) list([])
#   list([UUID('7645320f-3db3-41d0-b7d6-cb957f04f43e')])
#   list([UUID('503b2fef-a087-416e-ad1a-d1da6dc6686f')]) list([]) list([])
#   list([UUID('1f866935-7eb8-441d-94d0-fb892c73916a')])
#   list([UUID('d2b8c921-1fc1-454b-9c60-261de98c156f')]) list([])
#   list([UUID('b2881729-7912-4f03-aebc-75383eb00a76')])
#   list([UUID('d3f92557-1dce-4dc4-b960-901cfe81565a')]) list([]) list([])
#   list([]) list([]) list([UUID('ef3e5246-7649-489d-8331-c91f55e753eb')])
#   list([]) list([UUID('4f716afd-242c-41a7-b139-9ed5bd71745c')]) list([])
#   list([UUID('599d8467-346a-4f21-93d1-47e267ae7f09')])
#   list([UUID('09f00bab-7384-4d79-872a-826fd1aca128')])
#   list([UUID('ca22724f-88e0-4b74-bea8-b37306b44c95')])
#   list([UUID('da447c73-7b63-4ae4-814d-9e1e7c59abc9')]) list([]) list([])
#   list([UUID('9a5b35c9-265e-4ea2-9b45-7fd266d1e26b')])
#   list([UUID('7dc739f9-8f98-43d7-987d-5514f6fe7a75')])
#   list([UUID('222fca80-6ce9-4c71-bd10-beac6151df1c')]) list([])
#   list([UUID('99e29755-7b4d-42c1-9fc8-caebae6b25c9')])
#   list([UUID('f197dc40-ed52-4d90-858c-266427e74034')]) list([]) list([])
#   list([]) list([UUID('4159a99e-feec-4318-99d0-f9f3c8d9da62')])
#   list([UUID('03c66f8a-7867-4647-884b-82bbdeb0f6f5')]) list([])
#   list([UUID('07b5f179-319d-421a-bb43-2befbe350e38')])
#   list([UUID('4adb7dd2-99b5-4018-98ca-b4571375eb82')]) list([])
#   list([UUID('59b2f154-2460-4a7b-83a3-c75371f2286f')]) list([]) list([])
#   list([UUID('7103a985-7e4e-4ee6-9134-4c54f3c7120b')]) list([]) list([])
#   list([]) list([]) list([UUID('388e2da5-7115-471d-911f-83ae31128e22')])
#   list([UUID('58348667-9efd-4d6b-a505-7b4f1abc3674')]) list([]) list([])
#   list([UUID('aba09b28-00b4-4d21-aa17-305a364ad27b')])
#   list([UUID('9ea6b510-edcd-463b-ad34-5abb65f8dc18')])]]

# %% [markdown]
# # Tour

# %% [markdown]
# ### Fonctions de déplacement

# %% [markdown]
# ##### Renards

# %%
def reussite_chasse(efficacite_renard,efficacite_lapin):
    """donne un booléen qui correspond à l'issue de la chasse du renard"""
    return rd.random() < (efficacite_renard-efficacite_lapin)

# %%
def nb_renardeaux(age1,age2,fec1,fec2):
    """donne le nombre de renardeaux dans une portée aléatoirement"""
    #d : int
    d = 0
    if age1 > maturite_sexuelle_renard and age2 > maturite_sexuelle_renard:
        if (fec1 + fec2) / 2 >= 0.5:
            d = rd.choice([4,5])
    return d

# %%
def mouvement_renard(id_renard):

    _, renard = agents[id_renard]
    age, sexe, efficacite, fecondite, excitation, faim, gestationnaire, position = renard
    ligne, colonne = position
    en_gestation, jour, nb = gestationnaire

    #On met à jour ses variables
    age += 1 #il prend un jour de plus
    if age > esperance_vie_renard:
        environnement[ligne, colonne].remove(id_renard)
        return
    #le sexe ne change pas
    #l'efficacite ne change pasu
    #la fecondite ne change pas
    excitation += gain_excitation_renard
    faim += gain_faim_renard
    if faim > 1:
        environnement[ligne, colonne].remove(id_renard)
        return
    #on s'occupe du tuple gestationnaire
    if en_gestation:
        jour += 1
        if jour == temps_gestation_renard:
            cpt_renardeaux = 0
            while cpt_renardeaux < nb:
                cpt_renardeaux += 1
                creation_renard(1,(ligne, colonne))
            en_gestation = False
            jour = 0
            nb = 0
            gestationnaire = (en_gestation, jour, nb)
    #La position ne change pas
    
    entourage_moore = [] #liste des uuid aux environs
    
    for a in range((ligne-M),(ligne+M)+1):
        for b in range((colonne-M),(colonne+M)+1):
            for c in environnement[a%n,b%n]:
                    entourage_moore.append(c)
    
    #On retire les carottes de l'entourage
    entourage_moore_renard = []
    entourage_moore_lapin = []
    #On retire le renard considéré de son propre entourage
    entourage_moore.remove(id_renard)
    
    for e in entourage_moore:
        type_agent,_ = agents[e]
        if type_agent == "renard":
            entourage_moore_renard.append(e)
        elif type_agent == "lapin":
            entourage_moore_lapin.append(e)        
    
    #On examine si le renard veut manger ou se reproduire
    if ((faim >= excitation and len(entourage_moore_lapin) != 0) \
        or (faim < excitation and len(entourage_moore_lapin) != 0 and len(entourage_moore_renard)==0)) \
        and faim > seuil_renard and False:
        
        id_proie = rd.choice(entourage_moore_lapin)
        _,proie = agents[id_proie]
        age_proie, sexe_proie, efficacite_proie, fecondite_proie, excitation_proie, faim_proie, gestationnaire_proie, position_proie = proie
        ligne_proie, colonne_proie = position_proie
        
        if reussite_chasse(efficacite, efficacite_proie):
            environnement[ligne_proie, colonne_proie].remove(id_proie)
            faim = 0
        #On repack le tuple du renard
        position = (ligne_proie, colonne_proie)
        agents[id_renard] = ("renard", (age, sexe, efficacite, fecondite, excitation, faim, gestationnaire, position))
        environnement[ligne, colonne].remove(id_renard)
        environnement[ligne_proie, colonne_proie].append(id_renard)
        
    elif ((faim < excitation and len(entourage_moore_renard) != 0) \
          or (faim >= excitation and len(entourage_moore_lapin) == 0 and len(entourage_moore_renard) !=0)) \
        and excitation > seuil_renard and False:
        
        id_proie = rd.choice(entourage_moore_renard)
        _,proie = agents[id_proie]
        age_proie, sexe_proie, efficacite_proie, fecondite_proie, excitation_proie, faim_proie, gestationnaire_proie, position_proie = proie
        en_gestation_proie, jour_proie, nb_proie = gestationnaire_proie
        ligne_proie, colonne_proie = position_proie
        
        #Les deux sexes doivent être différents.
        #Aucun des deux ne doit être en gestation, et le male n'est jamais en gestation.
        if sexe_proie != sexe and en_gestation == en_gestation_proie:
            excitation = 0
            excitation_proie = 0
            if sexe:
                nb = nb_renardeaux(age, age_proie, fecondite, fecondite_proie)
                jour = temps_gestation_renard
                en_gestation = True
                gestationnaire = (en_gestation, jour, nb)
                position = (ligne_proie, colonne_proie)
            else:
                nb_proie = nb_renardeaux(age, age_proie, fecondite, fecondite_proie)
                jour_proie = temps_gestation_renard
                en_gestation_proie = True
                gestationnaire_proie = (en_gestation_proie, jour_proie, nb_proie)
                position = (ligne_proie, colonne_proie)
            agents[id_renard] = ("renard", (age, sexe, efficacite, fecondite, excitation, faim, gestationnaire, position))
            agents[id_proie] = ("renard", (age_proie, sexe_proie, efficacite_proie, fecondite_proie, excitation_proie, faim_proie, gestationnaire_proie, position_proie))
        environnement[ligne, colonne].remove(id_renard)
        environnement[ligne_proie, colonne_proie].append(id_renard)
    else:
        #Mouvement aléatoire
        environnement[ligne, colonne].remove(id_renard)
        ligne = ligne + rd.choice([-1,1])%n
        colonne = colonne + rd.choice([-1,1])%n
        #ligne = (ligne + rd.choice(range(-M,M+1)))%n
        #colonne = (colonne + rd.choice(range(-M,M+1)))%n
        environnement[ligne, colonne].append(id_renard)
        position = (ligne, colonne)
        agents[id_renard] = ("renard", (age, sexe, efficacite, fecondite, excitation, faim, gestationnaire, position))

# %% [markdown]
# ##### Lapins

# %%
def nb_lapinous(age1,age2,fec1,fec2):
    """donne le nombre de lapinous dans une portée en fonction des fécondités des parents"""
    #k:int
    k=0
    if age1>124 and age2>124:
        if (fec1+fec2)/2>=0.2:
            k=4+int(((fec1+fec2)/2-0.2)*10)
    return k

# %%
def mouvement_lapin(id_lapin):
    
    _, lapin = agents[id_lapin]
    age, sexe, efficacite, fecondite, excitation, faim, gestationnaire, position = lapin
    ligne, colonne = position
    en_gestation, jour, nb = gestationnaire
    
    #On met à jour ses variables
    age += 1 #il prend un jour de plus
    if age > esperance_vie_lapin or True:
        environnement[ligne, colonne].remove(id_lapin)
        return
    #le sexe ne change pas
    #l'efficacite ne change pas
    #la fecondite ne change pas
    excitation += gain_excitation_lapin
    faim += gain_faim_lapin
    if faim > 1:
        environnement[ligne, colonne].remove(id_lapin)
        return
    #on s'occupe du tuple gestationnaire
    if en_gestation:
        jour += 1
        if jour == temps_gestation_lapin:
            cpt_lapinous = 0
            while cpt_lapinous < nb:
                cpt_lapinous += 1
                creation_lapin(1,(ligne, colonne))
            en_gestation = False
            jour = 0
            nb = 0
            gestationnaire = (en_gestation, jour, nb)
    #La position ne change pas 
    
    entourage_moore = [] #liste des uuid aux environs
    
    for a in range((ligne-M),(ligne+M)+1):
        for b in range((colonne-M),(colonne+M)+1):
            for c in environnement[a%n,b%n]:
                entourage_moore.append(c)
    
    #On retire les renards de l'entourage
    #Cela implique qu'il n'y a pas d'interactions renard-lapin venant du lapin. Pas de fuite (?)
    entourage_moore_carotte = []
    entourage_moore_lapin = []
    #On retire le lapin considéré de son entourage propre
    entourage_moore.remove(id_lapin)
    
    for e in entourage_moore:
        type_agent,_ = agents[e]
        if type_agent == "carotte":
            entourage_moore_carotte.append(e)
        if type_agent == "lapin":
            entourage_moore_lapin.append(e)
    
    #On examine si le lapin veut manger ou se reproduire
    if ((faim >= excitation and len(entourage_moore_carotte) != 0) or (faim < excitation and len(entourage_moore_lapin) == 0 and len(entourage_moore_carotte)!=0)) and faim > seuil_lapin:
        
        #Cas de la prédation
        
        id_proie = rd.choice(entourage_moore_carotte)
        _, proie = agents[id_proie]
        nb_proie, position_proie = proie
        ligne_proie, colonne_proie = position_proie
        
        if nb_proie >= .1:
            nb_proie -= 0.1 #Mettre cette valeur en paramètre ???
            faim = 0
        #On repack le tuple du lapin et de la carotte
        position = (ligne_proie, colonne_proie)
        agents[id_lapin] = ("lapin", (age, sexe, efficacite, fecondite, excitation, faim, gestationnaire, position))
        agents[id_proie] = ("carotte", (nb_proie, position_proie))
        environnement[ligne, colonne].remove(id_lapin)
        environnement[ligne_proie, colonne_proie].append(id_lapin)
        
    elif ((faim < excitation and len(entourage_moore_lapin) != 0) or (faim >= excitation and len(entourage_moore_carotte) == 0 and len(entourage_moore_lapin) !=0)) and excitation > seuil_lapin:
        
        #Cas de la reproduction
        
        id_proie = rd.choice(entourage_moore_lapin)
        _,proie = agents[id_proie]
        age_proie, sexe_proie, efficacite_proie, fecondite_proie, excitation_proie, faim_proie, gestationnaire_proie, position_proie = proie
        en_gestation_proie, jour_proie, nb_proie = gestationnaire_proie
        ligne_proie, colonne_proie = position_proie
        
        #Les deux sexes doivent être différents.
        #Aucun des deux ne doit être en gestation, et le male n'est jamais en gestation.
        if sexe_proie != sexe and en_gestation == en_gestation_proie:
            excitation = 0
            excitation_proie = 0
            if sexe:
                nb = nb_lapinous(age, age_proie, fecondite, fecondite_proie)
                jour = temps_gestation_lapin
                en_gestation = True
                gestationnaire = (en_gestation, jour, nb)
                position = (ligne_proie, colonne_proie)
            else:
                nb_proie = nb_lapinous(age, age_proie, fecondite, fecondite_proie)
                jour_proie = temps_gestation_lapin
                en_gestation_proie = True
                gestationnaire_proie = (en_gestation_proie, jour_proie, nb_proie)
                position = (ligne_proie, colonne_proie)
            agents[id_lapin] = ("lapin", (age, sexe, efficacite, fecondite, excitation, faim, gestationnaire, position))
            agents[id_proie] = ("lapin", (age_proie, sexe_proie, efficacite_proie, fecondite_proie, excitation_proie, faim_proie, gestationnaire_proie, position_proie))
        environnement[ligne, colonne].remove(id_lapin)
        environnement[ligne_proie, colonne_proie].append(id_lapin)
    else:
        #Mouvement aléatoire
        #print(environnement[ligne, colonne])
        environnement[ligne, colonne].remove(id_lapin)
        ligne = (ligne + rd.choice(range(-M,M+1)))%n
        colonne = (colonne + rd.choice(range(-M,M+1)))%n
        environnement[ligne, colonne].append(id_lapin)
        position = (ligne, colonne)
        agents[id_lapin] = ("lapin", (age, sexe, efficacite, fecondite, excitation, faim, gestationnaire, position))

# %% [markdown]
# ##### Carottes

# %%
def mouvement_carotte(id_carotte):
    _, carotte = agents[id_carotte]
    densite, position = carotte
    densite += gain_densite_carotte
    (densite, position) = carotte
    agents[id_carotte] = ("carotte", carotte)

# %% [markdown]
# ### Fonction de tour

# %%
def tour():
    for a in agents:
        type_agent, agent = agents[a]
        if type_agent == "renard":
            _, _, _, _, _, _, _, position = agent
            ligne, colonne = position
            if a in environnement[ligne, colonne]:
                mouvement_renard(a)
            
        elif type_agent == "lapin":
            _, _, _, _, _, _, _, position = agent
            ligne, colonne = position
            if a in environnement[ligne, colonne]:
                mouvement_lapin(a)
        
        else:
            _, position = agent
            ligne, colonne = position
            if a in environnement[ligne, colonne]:
                mouvement_carotte(a)
    
    matrice_renard, matrice_lapin, matrice_carotte = casse_matrice()
    results_renard.append(matrice_renard)
    results_lapin.append(matrice_lapin)
    results_carotte.append(matrice_carotte)
    
    return environnement

# %%
def tours(nb_tour):
    #Exécute n fois la fonction tour, avec n un nombre de jours
    cpt = 0
    while cpt < nb_tour:
        cpt += 1
        tour()
    return environnement

# %% [markdown]
# # Exécution complète

# %%
results_renard = []
results_lapin = []
results_carotte = []

def execution_complete(nb_tour):
    
    results_renard.append(np.zeros((100,100)))
    results_lapin.append(np.zeros((100,100)))
    results_carotte.append(np.zeros((100,100)))

    #On init la matrice
    init_matrice()
    #On init le dico des agents
    agents = merge_two_dicts(creation_carottes(),merge_two_dicts(creation_lapins(), creation_renards()))
    #On update la matrice avec les uuid du dico
    update_matrice()
    #On exécute n tours
    tours(nb_tour)
    return (results_renard, results_lapin, results_carotte)

# %%
#print(execution_complete(100))

# %%
np.set_printoptions(threshold=np.inf)

def casse_matrice():

    matrice_renard = np.zeros((100,100))
    matrice_lapin = np.zeros((100,100))
    matrice_carotte = np.zeros((100,100))

    cpt_ligne = 0
    cpt_colonne = 0
    cpt_renard = 0
    cpt_lapin = 0
    densite = 0

    for a in environnement:
        cpt_ligne += 1
        for b in a:
            cpt_colonne += 1
            for c in b:
                type_agent,agent = agents[c]
                if type_agent == "lapin":
                    cpt_lapin += 1
                if type_agent == "renard":
                    cpt_renard += 1
                    #print(cpt_renard)
                if type_agent == "carotte":
                    densite,_ = agent
                matrice_carotte[cpt_ligne-1, cpt_colonne-1] = densite
                densite = 0
            matrice_renard[cpt_ligne-1, cpt_colonne-1] = cpt_renard
            matrice_lapin[cpt_ligne-1, cpt_colonne-1] = cpt_lapin            
            cpt_lapin = 0
            cpt_renard = 0
        cpt_colonne = 0
    return (matrice_renard, matrice_lapin, matrice_carotte)

#print(casse_matrice())

# %%
# %matplotlib notebook

# %%
matrice_renard, matrice_lapin, _ = casse_matrice()

terrain2chass = matrice_renard
size = np.array(terrain2chass.shape)
dpi = 72.0
figsize = size[1]/float(dpi),size[0]/float(dpi)
fig = plt.figure(figsize = figsize, dpi = dpi, facecolor = "white")
fig.add_axes([0.0, 0.0, 1.0, 1.0], frameon = False)
im=plt.imshow(terrain2chass, interpolation = 'nearest', cmap = plt.cm.gray_r)
# Out:
# <img src="data:image/png;base64,..." width="100">

# %%
nb_jour = 100

execution_complete(nb_jour)

fig = plt.figure()

# results[i] contient l'état au pas de temps i sous forme de matrice
im = plt.imshow(results_renard[0], animated=True, cmap = plt.cm.gray_r)

def updatefig(i):
    im.set_array(results_renard[i+1])
    return im

ani = animation.FuncAnimation(fig, updatefig, frames=nb_jour, interval=200, blit=True)


#mywriter = animation.FFMpegWriter()

#ani.save('basic_animation_test.mp4',writer=mywriter)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-43-6f4caa0f4b3e> in <module>()
#       1 nb_jour = 100
#       2
# ----> 3 execution_complete(nb_jour)
#       4
#       5 fig = plt.figure()
#
# <ipython-input-36-c2ab6dfd281d> in execution_complete(nb_tour)
#      16     update_matrice()
#      17     #On exécute n tours
# ---> 18     tours(nb_tour)
#      19     return (results_renard, results_lapin, results_carotte)
#
# <ipython-input-35-6ccced3c3579> in tours(nb_tour)
#       4     while cpt < nb_tour:
#       5         cpt += 1
# ----> 6         tour()
#       7     return environnement
#
# <ipython-input-34-3eefd1bc80cf> in tour()
#       6             ligne, colonne = position
#       7             if a in environnement[ligne, colonne]:
# ----> 8                 mouvement_renard(a)
#       9
#      10         elif type_agent == "lapin":
#
# <ipython-input-30-2ff1d8a3fe13> in mouvement_renard(id_renard)
#     106         #ligne = (ligne + rd.choice(range(-M,M+1)))%n
#     107         #colonne = (colonne + rd.choice(range(-M,M+1)))%n
# --> 108         environnement[ligne, colonne].append(id_renard)
#     109         position = (ligne, colonne)
#     110         agents[id_renard] = ("renard", (age, sexe, efficacite, fecondite, excitation, faim, gestationnaire, position))
#
# IndexError: index 197 is out of bounds for axis 1 with size 100
